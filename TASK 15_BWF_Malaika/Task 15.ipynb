# %% [markdown]
# # 🔴 Task 15: Data Wrangling: Join, Combine, and Reshape.
# #### Submitted by: Malaika Ahmed

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Merge two DataFrames on a single key

# %%
# Creating first DataFrame

df1=pd.DataFrame({'KEY': ['a','b','c','d','e','f'] ,'Data1':range(6)})

# %%
df1
# Out:
#   KEY  Data1
# 0   a      0
# 1   b      1
# 2   c      2
# 3   d      3
# 4   e      4
# 5   f      5

# %%
# creating second DataFrame

df2=pd.DataFrame({'KEY': ['c','d','e'] ,'Data2':[6,7,8]})

# %%
df2
# Out:
#   KEY  Data2
# 0   c      6
# 1   d      7
# 2   e      8

# %%
df_merge_s=pd.merge(df1,df2,on='KEY')
df_merge_s
# Out:
#   KEY  Data1  Data2
# 0   c      2      6
# 1   d      3      7
# 2   e      4      8

# %% [markdown]
# ## 2. Merge two DataFrames on multiple keys.

# %%
# Creating first Data Frame
df3=pd.DataFrame({'KEY1': ['a','b','c'],'KEY2':['d','e','f'] ,'Data1':range(3)})

# %%
df3
# Out:
#   KEY1 KEY2  Data1
# 0    a    d      0
# 1    b    e      1
# 2    c    f      2

# %%
# Creating second Data Frame
df4=pd.DataFrame({'KEY1': ['a','b','x'],'KEY2':['d','e','w'] ,'Data2':[5,6,7]})

# %%
df4
# Out:
#   KEY1 KEY2  Data2
# 0    a    d      5
# 1    b    e      6
# 2    x    w      7

# %%
df_merge_m=pd.merge(df3,df4,on= ['KEY1','KEY2'])
df_merge_m
# Out:
#   KEY1 KEY2  Data1  Data2
# 0    a    d      0      5
# 1    b    e      1      6

# %% [markdown]
# ## 3. Perform an outer join, inner join, left join, and right join.

# %%
# First DataFrame
df5=pd.DataFrame({'lKEY': ['a','b','c','d','e','f'] ,'Data1':range(6)})

# %%
df5
# Out:
#   lKEY  Data1
# 0    a      0
# 1    b      1
# 2    c      2
# 3    d      3
# 4    e      4
# 5    f      5

# %%
# Second DataFrame
df6=pd.DataFrame({'rKEY': ['c','d','e'] ,'Data2':[6,7,8]})

# %%
df6
# Out:
#   rKEY  Data2
# 0    c      6
# 1    d      7
# 2    e      8

# %%
# Merging using left,right and inner join
# inner join is like intersection of two dataframes

df_merge_i = pd.merge(df5, df6, left_on='lKEY', right_on='rKEY',how='inner')

# %%
df_merge_i
# Out:
#   lKEY  Data1 rKEY  Data2
# 0    c      2    c      6
# 1    d      3    d      7
# 2    e      4    e      8

# %%
# Merging using left,right and outer join
# outer join is like union of two dataframes

df_merge_o = pd.merge(df5, df6, left_on='lKEY', right_on='rKEY',how='outer')
df_merge_o
# Out:
#   lKEY  Data1 rKEY  Data2
# 0    a      0  NaN    NaN
# 1    b      1  NaN    NaN
# 2    c      2    c    6.0
# 3    d      3    d    7.0
# 4    e      4    e    8.0
# 5    f      5  NaN    NaN

# %% [markdown]
# ## 4. Concatenate two DataFrames along rows.

# %%
# First DataFrame
df1
# Out:
#   KEY  Data1
# 0   a      0
# 1   b      1
# 2   c      2
# 3   d      3
# 4   e      4
# 5   f      5

# %%
# Second DataFrame
df2
# Out:
#   KEY  Data2
# 0   c      6
# 1   d      7
# 2   e      8

# %%
df_concat=pd.concat([df1,df2])
df_concat
# Out:
#   KEY  Data1  Data2
# 0   a    0.0    NaN
# 1   b    1.0    NaN
# 2   c    2.0    NaN
# 3   d    3.0    NaN
# 4   e    4.0    NaN
# 5   f    5.0    NaN
# 0   c    NaN    6.0
# 1   d    NaN    7.0
# 2   e    NaN    8.0

# %% [markdown]
# ## 5. Concatenate two DataFrames along columns.

# %%
# First DataFrame
df1
# Out:
#   KEY  Data1
# 0   a      0
# 1   b      1
# 2   c      2
# 3   d      3
# 4   e      4
# 5   f      5

# %%
# Second DataFrame
df2
# Out:
#   KEY  Data2
# 0   c      6
# 1   d      7
# 2   e      8

# %%
df_concat1=pd.concat([df1,df2],axis=1)
df_concat1
# Out:
#   KEY  Data1  KEY  Data2
# 0   a      0    c    6.0
# 1   b      1    d    7.0
# 2   c      2    e    8.0
# 3   d      3  NaN    NaN
# 4   e      4  NaN    NaN
# 5   f      5  NaN    NaN

# %% [markdown]
# ## 6. Concatenate a list of DataFrames

# %%
# Importing csv file 

pd.read_csv("Desktop/TASK#15_BWF_Malaika/Fortune 500 2017 - Fortune 500.csv")
# Out:
#      Rank               Title                           Website  Employees  \
# 0       1             Walmart            http://www.walmart.com    2300000
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2       3               Apple              http://www.apple.com     116000
# 3       4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4       5            McKesson           http://www.mckesson.com      68000
# ..    ...                 ...                               ...        ...
# 495   496       Michaels Cos.           http://www.michaels.com      31000
# 496   497       Toll Brothers       http://www.tollbrothers.com       4200
# 497   498               Yahoo              http://www.yahoo.com       8500
# 498   499       Vistra Energy       http://www.vistraenergy.com       4431
# 499   500      ABM Industries                http://www.abm.com     110000
#
# ...

# %%
df = pd.read_csv("Desktop/TASK#15_BWF_Malaika/Fortune 500 2017 - Fortune 500.csv")

# %%
# Creating list of DataFrames 
# Mini Data Frame1
df1=df[0:5]
df1
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
# Mini Data Frame2

df2=df[5:10]
df2
# Out:
#    Rank               Title                           Website  Employees  \
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 5             Health Care   Health Care: Insurance and Managed Care
# 6             Health Care  Health Care: Pharmacy and Other Services
# 7  Motor Vehicles & Parts                  Motor Vehicles and Parts
# 8      Telecommunications                        Telecommunications
# 9  Motor Vehicles & Parts                  Motor Vehicles and Parts
#
#        Hqlocation                  Hqaddr      Hqcity Hqstate  ...  \
# ...

# %%
# Mini Data Frame3

df3=df[10:15]
df3
# Out:
#     Rank              Title                           Website  Employees  \
# 10    11  AmerisourceBergen  http://www.amerisourcebergen.com      18500
# 11    12         Amazon.com             http://www.amazon.com     341400
# 12    13   General Electric                 http://www.ge.com     295000
# 13    14            Verizon            http://www.verizon.com     160900
# 14    15    Cardinal Health     http://www.cardinalhealth.com      37300
#
#                 Sector                         Industry        Hqlocation  \
# 10         Wholesalers         Wholesalers: Health Care  Chesterbrook, PA
# 11          Technology  Internet Services and Retailing       Seattle, WA
# 12         Industrials             Industrial Machinery        Boston, MA
# 13  Telecommunications               Telecommunications      New York, NY
# 14         Wholesalers         Wholesalers: Health Care        Dublin, OH
#
#                        Hqaddr        Hqcity Hqstate  ...  \
# ...

# %%
# Mini Data Frame4

df4=df[15:20]
df4
# Out:
#     Rank                     Title                                Website  \
# 15    16                    Costco                  http://www.costco.com
# 16    17  Walgreens Boots Alliance  http://www.walgreensbootsalliance.com
# 17    18                    Kroger             http://www.thekrogerco.com
# 18    19                   Chevron                 http://www.chevron.com
# 19    20                Fannie Mae               http://www.fanniemae.com
#
#     Employees              Sector                Industry      Hqlocation  \
# 15     172000           Retailing   General Merchandisers    Issaquah, WA
# 16     300000  Food & Drug Stores    Food and Drug Stores   Deerfield, IL
# 17     443000  Food & Drug Stores    Food and Drug Stores  Cincinnati, OH
# 18      55200              Energy      Petroleum Refining   San Ramon, CA
# 19       7000          Financials  Diversified Financials  Washington, DC
#
#                        Hqaddr      Hqcity Hqstate  ...  \
# ...

# %%
# Mini Data Frame5

df5=df[20:25]
df5
# Out:
#     Rank                    Title                         Website  Employees  \
# 20    21        J.P. Morgan Chase    http://www.jpmorganchase.com     243355
# 21    22  Express Scripts Holding  http://www.express-scripts.com      25600
# 22    23               Home Depot        http://www.homedepot.com     406000
# 23    24                   Boeing           http://www.boeing.com     150540
# 24    25              Wells Fargo       http://www.wellsfargo.com     269100
#
#                  Sector                                  Industry  \
# 20           Financials                          Commercial Banks
# 21          Health Care  Health Care: Pharmacy and Other Services
# 22            Retailing                Specialty Retailers: Other
# 23  Aerospace & Defense                     Aerospace and Defense
# 24           Financials                          Commercial Banks
#
#            Hqlocation                  Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
df_list=[df1,df2,df3,df4,df5]

# %%
# Concatenating all 5 of mini data frames

df_concat_list=pd.concat(df_list)
df_concat_list
# Out:
#     Rank                     Title                                Website  \
# 0      1                   Walmart                 http://www.walmart.com
# 1      2        Berkshire Hathaway       http://www.berkshirehathaway.com
# 2      3                     Apple                   http://www.apple.com
# 3      4               Exxon Mobil              http://www.exxonmobil.com
# 4      5                  McKesson                http://www.mckesson.com
# 5      6        UnitedHealth Group       http://www.unitedhealthgroup.com
# 6      7                CVS Health               http://www.cvshealth.com
# 7      8            General Motors                      http://www.gm.com
# 8      9                      AT&T                     http://www.att.com
# 9     10                Ford Motor                    http://www.ford.com
# 10    11         AmerisourceBergen       http://www.amerisourcebergen.com
# 11    12                Amazon.com                  http://www.amazon.com
# ...

# %% [markdown]
# ## 7. Reshape data using the melt function to go from wide to long format.

# %%
df1=df[0:5]
df1
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %% [markdown]
# #### Extracting numerical columns from DataFrame df1

# %%
df2=df1[['Title','Employees','Revenues','Profits']]

df2
# Out:
#                 Title  Employees  Revenues  Profits
# 0             Walmart    2300000    485873  13643.0
# 1  Berkshire Hathaway     367700    223604  24074.0
# 2               Apple     116000    215639  45687.0
# 3         Exxon Mobil      72700    205004   7840.0
# 4            McKesson      68000    192487   2258.0

# %%
pd.melt(df2,id_vars='Title')
# Out:
#                  Title   variable      value
# 0              Walmart  Employees  2300000.0
# 1   Berkshire Hathaway  Employees   367700.0
# 2                Apple  Employees   116000.0
# 3          Exxon Mobil  Employees    72700.0
# 4             McKesson  Employees    68000.0
# 5              Walmart   Revenues   485873.0
# 6   Berkshire Hathaway   Revenues   223604.0
# 7                Apple   Revenues   215639.0
# 8          Exxon Mobil   Revenues   205004.0
# 9             McKesson   Revenues   192487.0
# 10             Walmart    Profits    13643.0
# 11  Berkshire Hathaway    Profits    24074.0
# 12               Apple    Profits    45687.0
# 13         Exxon Mobil    Profits     7840.0
# 14            McKesson    Profits     2258.0

# %%
df3=pd.melt(df2,id_vars='Title')

# %% [markdown]
# ## 8. Create a pivot table to summarize data.

# %%
df3=pd.melt(df2,id_vars='Title')

df3.pivot_table(index='variable',values='value',aggfunc=['mean'])
# Out:
#                mean
#               value
# variable
# Employees  405294.0
# Profits     13283.5
# Revenues   216693.9

# %% [markdown]
# ## 9. Group data by one or more columns and perform aggregation functions (e.g., sum, mean, count).

# %%
df2=df1[['Title','Employees','Revenues','Profits']]

df2
# Out:
#                 Title  Employees  Revenues  Profits
# 0             Walmart    2300000    485873  13643.0
# 1  Berkshire Hathaway     367700    223604  24074.0
# 2               Apple     116000    215639  45687.0
# 3         Exxon Mobil      72700    205004   7840.0
# 4            McKesson      68000    192487   2258.0

# %%
# Creating group by of column "Title"

df2.groupby('Title')

# %%
df2_gby=df2.groupby('Title')

# %% [markdown]
# #### Mean using agg function

# %%
mean_data = df2_gby.agg({
    'Employees': ['mean'],
    'Revenues': ['mean'],
    'Profits': ['mean']
})

# %%
mean_data
# Out:
#                     Employees  Revenues  Profits
#                          mean      mean     mean
# Title
# Apple                116000.0  215639.0  45687.0
# Berkshire Hathaway   367700.0  223604.0  24074.0
# Exxon Mobil           72700.0  205004.0   7840.0
# McKesson              68000.0  192487.0   2258.0
# Walmart             2300000.0  485873.0  13643.0

# %% [markdown]
# #### Sum using agg function

# %%
sum_data = df2_gby.agg({
    'Employees': ['sum'],
    'Revenues': ['sum'],
    'Profits': ['sum']
})

# %%
sum_data
# Out:
#                    Employees Revenues  Profits
#                          sum      sum      sum
# Title
# Apple                 116000   215639  45687.0
# Berkshire Hathaway    367700   223604  24074.0
# Exxon Mobil            72700   205004   7840.0
# McKesson               68000   192487   2258.0
# Walmart              2300000   485873  13643.0

# %% [markdown]
# #### Count using agg function

# %%
count_data = df2_gby.agg({
    'Employees': ['count'],
    'Revenues': ['count'],
    'Profits': ['count']
})

# %%
count_data
# Out:
#                    Employees Revenues Profits
#                        count    count   count
# Title
# Apple                      1        1       1
# Berkshire Hathaway         1        1       1
# Exxon Mobil                1        1       1
# McKesson                   1        1       1
# Walmart                    1        1       1

# %%
count_data.sum()
# Out:
# Employees    5
# Revenues     5
# Profits      5
# dtype: int64

# %% [markdown]
# ## 10. Apply multiple aggregation functions to grouped data.

# %%
# Extracting mini DataFrame consisting of 0 to 9 rows
df1=df[0:10]
df1
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# ...

# %%
# Extracting numerical columns and creating group by on column "Title"
df2=df1[['Title','Employees','Revenues','Profits']]
df2.groupby("Title")

# %%
df3=df2.groupby("Title")

# %%
# Applying different aggregation function at once to grouped data df3

df3.agg({'Employees':['mean'],'Revenues':['sum'],'Profits':['max']})
# Out:
#                     Employees Revenues  Profits
#                          mean      sum      max
# Title
# AT&T                 268540.0   163786  12976.0
# Apple                116000.0   215639  45687.0
# Berkshire Hathaway   367700.0   223604  24074.0
# CVS Health           204000.0   177526   5317.0
# Exxon Mobil           72700.0   205004   7840.0
# Ford Motor           201000.0   151800   4596.0
# General Motors       225000.0   166380   9427.0
# McKesson              68000.0   192487   2258.0
# UnitedHealth Group   230000.0   184840   7017.0
# Walmart             2300000.0   485873  13643.0

# %% [markdown]
# ## 11. Use the groupby function to group data and apply custom functions.

# %% [markdown]
# #### Using df2 DataFrame from pervious question

# %%
df2
# Out:
#                 Title  Employees  Revenues  Profits
# 0             Walmart    2300000    485873  13643.0
# 1  Berkshire Hathaway     367700    223604  24074.0
# 2               Apple     116000    215639  45687.0
# 3         Exxon Mobil      72700    205004   7840.0
# 4            McKesson      68000    192487   2258.0
# 5  UnitedHealth Group     230000    184840   7017.0
# 6          CVS Health     204000    177526   5317.0
# 7      General Motors     225000    166380   9427.0
# 8                AT&T     268540    163786  12976.0
# 9          Ford Motor     201000    151800   4596.0

# %% [markdown]
# ### Defining "agg sum" function

# %%
def sum(df3):
  
    sum = df3.agg({
        'Employees': ['sum'],
        'Revenues': ['sum'],
        'Profits': ['sum']
    })
    return sum



sum(df3)
# Out:
#                    Employees Revenues  Profits
#                          sum      sum      sum
# Title
# AT&T                  268540   163786  12976.0
# Apple                 116000   215639  45687.0
# Berkshire Hathaway    367700   223604  24074.0
# CVS Health            204000   177526   5317.0
# Exxon Mobil            72700   205004   7840.0
# Ford Motor            201000   151800   4596.0
# General Motors        225000   166380   9427.0
# McKesson               68000   192487   2258.0
# UnitedHealth Group    230000   184840   7017.0
# Walmart              2300000   485873  13643.0

# %% [markdown]
# ### Defining "agg min" function

# %%
def min(df3):
  
    min= df3.agg({
        'Employees': ['min'],
        'Revenues': ['min'],
        'Profits': ['min']
    })
    return min



min(df3)
# Out:
#                    Employees Revenues  Profits
#                          min      min      min
# Title
# AT&T                  268540   163786  12976.0
# Apple                 116000   215639  45687.0
# Berkshire Hathaway    367700   223604  24074.0
# CVS Health            204000   177526   5317.0
# Exxon Mobil            72700   205004   7840.0
# Ford Motor            201000   151800   4596.0
# General Motors        225000   166380   9427.0
# McKesson               68000   192487   2258.0
# UnitedHealth Group    230000   184840   7017.0
# Walmart              2300000   485873  13643.0

# %% [markdown]
# ### Defining "agg mean" function

# %%
def mean(df3):
  
    mean= df3.agg({
        'Employees': ['mean'],
        'Revenues': ['mean'],
        'Profits': ['mean']
    })
    return mean


mean(df3)
# Out:
#                     Employees  Revenues  Profits
#                          mean      mean     mean
# Title
# AT&T                 268540.0  163786.0  12976.0
# Apple                116000.0  215639.0  45687.0
# Berkshire Hathaway   367700.0  223604.0  24074.0
# CVS Health           204000.0  177526.0   5317.0
# Exxon Mobil           72700.0  205004.0   7840.0
# Ford Motor           201000.0  151800.0   4596.0
# General Motors       225000.0  166380.0   9427.0
# McKesson              68000.0  192487.0   2258.0
# UnitedHealth Group   230000.0  184840.0   7017.0
# Walmart             2300000.0  485873.0  13643.0
