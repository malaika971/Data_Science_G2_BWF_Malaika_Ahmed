# %% [markdown]
# # 🔴 Task 16: Introduction to Matplotlib (basic plots: line, scatter, bar)
# #### Summitted by Malaika Ahmed

# %% [markdown]
# ## 🟡 Basic Plots

# %% [markdown]
# ###  1.Create a simple line plot.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# IMPORTING CSV FILE

# %%
pd.read_csv('weatherdata.csv')
# Out:
#             Location        Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  1/14/2024 21:12      10.683001     41.195754
# 1          San Diego  5/17/2024 15:22       8.734140     58.319107
# 2          San Diego   5/11/2024 9:30      11.632436     38.820175
# 3       Philadelphia  2/26/2024 17:32      -8.628976     54.074474
# 4        San Antonio  4/29/2024 13:23      39.808213     72.899908
# ...              ...              ...            ...           ...
# 999915       Phoenix  4/29/2024 20:49      13.335441     39.649131
# 999916      New York  1/30/2024 15:04       1.837912     66.505813
# 999917   Los Angeles  3/27/2024 12:25      34.641340     78.108101
# 999918  Philadelphia   4/6/2024 23:13      25.456678     37.764932
# 999919        Dallas  4/20/2024 19:37      12.781843     71.636138
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# 1               9.111623       27.715161
# ...

# %%
df=pd.read_csv('weatherdata.csv')

# %% [markdown]
# #### 🔹 Extracting mini data set

# %%
df1=df[0:6]
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

# %%
x
# Out:
# 0     8.233540
# 1    27.715161
# 2    28.732951
# 3    26.367303
# 4    29.898622
# 5    27.473896
# Name: Wind_Speed_kmh, dtype: float64

# %%
y
# Out:
# 0    10.683001
# 1     8.734140
# 2    11.632436
# 3    -8.628976
# 4    39.808213
# 5    27.341055
# Name: Temperature_C, dtype: float64

# %%
plt.plot(x,y,)
plt.title('SIMPLE LINE PLOT')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ### 2. Plot multiple lines on the same graph

# %%
x=df1['Wind_Speed_kmh']
y1=df1['Temperature_C']
y2=df1['Humidity_pct']
y3=df1['Precipitation_mm']

plt.plot(x,y1,label='Temp & humidity')
plt.plot(x,y2,label='Temp and windspeed')
plt.plot(x,y3,label='Temp and precipitation')

plt.title('LINE PLOT with multiple lines')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.legend( )
plt.show()

# %% [markdown]
# ### 3. Add markers to a line plot

# %% [markdown]
# #### 🔹 LINE plot with marker style :circle

# %%
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.plot(x,y,marker='o',ms='10')
plt.title('LINE plot with marker style :circle')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# #### 🔹 LINE plot with marker style : Hexagon

# %%
plt.plot(x,y,marker='h',ms='10')
plt.title('LINE PLOT with marker style : Hexagon')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
#  #### 🔹 LINE PLOT with marker style : Diamond

# %%
plt.plot(x,y,marker='d',ms='10')
plt.title('LINE PLOT with marker style :diamond')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# #### 🔹 LINE PLOT with marker style :Triangle

# %%
plt.plot(x,y,marker='^',ms='10')
plt.title('LINE PLOT with marker style :Triangle')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# #### 🔹 LINE PLOT with marker style : Star

# %%
plt.plot(x,y,marker='*',ms='10')
plt.title('LINE PLOT with marker sytle *')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ### Custom Marker edge colors

# %%
plt.plot(x,y,marker='o',ms='10',mec='r')
plt.title('LINE PLOT \n Marker style: Circle \n Marker edge color: Red')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
plt.plot(x,y,marker='h',ms='10',mec='r',mfc='y')
plt.title('LINE PLOT \n Marker style: Hexagon \n Marker edge color: Red \n Marker filled color: Yellow')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ## 4.Customize line styles and colors

# %%
# Customize line styles and colors.
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.plot(x,y,ls='dotted',color='r')
plt.title('LINE PLOT \n  style: dotted \n  color: Red')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.plot(x,y,ls='dashed',color='b')
plt.title('LINE PLOT \n  style: dash \n  color: Blue')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.plot(x,y,ls='None',marker='o',color='g')
plt.title('LINE PLOT with markers only( in green color )')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
# line width 

# Customize line styles and colors.
x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.plot(x,y,ls='dotted',color='r',lw='5')
plt.title('LINE PLOT \n  style: dotted \n  color: Red \n  width =5')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ##  🟡 Scatter Plots

# %% [markdown]
# ### 3. Create a basic scatter plot.

# %%
df1=df[0:10]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']


plt.scatter(x,y)
plt.title('Basic Scatter Plot')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ### 2. Customize marker styles, sizes, and colors

# %%
df1=df[0:10]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']


plt.scatter(x,y,marker='^',color='g',s=50)
plt.title('Scatter Plot \n Marker Style: Triangle \n Color : Green \n Size = 50')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
# Different color and different size of each point

df1=df[0:10]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']
color=['red','blue','green','brown','orange','black','yellow','red','green','black']
size=[180,150,250,125,800,250,160,350,500,200]
plt.scatter(x,y,marker='.',c=color,s=size)
plt.title('Scatter Plot \n Marker Style: Point \n Different sizes and colors for each point')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
# Different color and different size of each point with colour bar
df1=df[0:10]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']
color=['red','blue','green','brown','orange','black','yellow','red','green','black']
size=[180,150,170,125,140,250,160,280,155,200]
plt.scatter(x,y,marker='.',c=color,s=size)
plt.title('Scatter Plot \n Marker Style: Point \n Different sizes and colors for each point \n With color bar')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')
plt.colorbar()
plt.show()

# %% [markdown]
# ## 3. Plot multiple scatter plots on the same graph.

# %%
# Multiple scatter plots on the same graph.


import matplotlib.pyplot as plt
df1=df[0:5]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.scatter(x,y,marker='.',color='red',s=150)


df2=df[5:10]

x=df2['Wind_Speed_kmh']
y=df2['Temperature_C']
plt.scatter(x,y,marker='.',color='blue',s=200)



df3=df[10:15]

x=df3['Wind_Speed_kmh']
y=df3['Temperature_C']
plt.scatter(x,y,marker='.',color='green',s=250)



plt.show()

# %% [markdown]
# ### 4. Add labels and titles to the scatter plot.

# %%
# labels and titles to the scatter plot.
df1=df[0:5]

x=df1['Wind_Speed_kmh']
y=df1['Temperature_C']

plt.scatter(x,y,marker='.',color='red',s=150, label='2021')


df2=df[5:10]

x=df2['Wind_Speed_kmh']
y=df2['Temperature_C']
plt.scatter(x,y,marker='.',color='blue',s=200, label='2022')

df3=df[10:15]

x=df3['Wind_Speed_kmh']
y=df3['Temperature_C']
plt.scatter(x,y,marker='.',color='green',s=250, label='2023')

plt.title('Scatter Plot \n Marker Style: Point \n Different sizes and colors with labels')
plt.xlabel('Wind_Speed(kmh)')
plt.ylabel('TEMPERATURE (C)')

plt.legend()
plt.show()

# %% [markdown]
# ## 🟡 Bar Charts

# %% [markdown]
# ### `1. Create a vertical bar chart.

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Temperature_C']  

plt.bar(x,y)
plt.title('Vertical Bar Chart')
plt.xlabel('Location')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ### 2. Create a horizontal bar chart

# %%
x=df1['Temperature_C']
y=df2['Location']  

plt.barh(x,y)
plt.title('Horizontal Bar Chart')
plt.xlabel('Location')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ### 3 Customize bar colors and add edge colors.

# %%
x=df1['Location']
y=df2['Temperature_C']  
c=['blue','green','red','black','orange']
w=[0.2,0.3,0.5,0.4,0.6]
plt.bar(x,y,color=c,width=w)
plt.title('Vertical Bar Chart \n Different colored bars with varying width')
plt.xlabel('Location')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
x=df1['Location']
y=df2['Temperature_C']  
c=['blue','green','red','black','orange']
h=[0.2,0.3,0.5,0.4,0.6]
plt.barh(x,y,color=c,height=h)
plt.title('Horizontal Bar Chart \n Different colored bars with varying height')
plt.xlabel('Temperature')
plt.ylabel('Location')

plt.show()

# %% [markdown]
# ### Adding edge colors

# %%
x=df1['Location']
y=df2['Temperature_C']  

plt.bar(x,y,color='yellow',edgecolor='red',width=0.2)
plt.title('Vertical Bar Chart \n Edge color: Red')
plt.xlabel('Location')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %%
x=df1['Temperature_C']
y=df2['Location']  

plt.barh(x,y,color='yellow',edgecolor='black',height=0.5)
plt.title('Horizontal Bar Chart \n Edge Color : Black')
plt.xlabel('Location')
plt.ylabel('TEMPERATURE (C)')

plt.show()

# %% [markdown]
# ## 🟡 Pie Charts

# %% [markdown]
# ### 1. Create a basic pie chart

# %%
df1=df[20:25]
df2=df[25:30]

# Create a vertical bar chart.
x=df1['Location']
y=df2['Wind_Speed_kmh']  

plt.pie(y)
plt.title('Pie Chart')


plt.show()

# %% [markdown]
# ## 2.Customize slice colors and add a legend.

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Wind_Speed_kmh']  

plt.pie(y,labels=x)
plt.title('Pie Chart with labels')

plt.legend()
plt.show()

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Wind_Speed_kmh']  

Color=['red','blue','green','yellow','orange']
plt.pie(y,labels=x,startangle=90,colors=Color)
plt.title('Pie Chart with customized colors and labels')

plt.legend(title='LOCATION')
plt.show()

# %% [markdown]
# ## 3.Explode a slice of the pie chart.

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Wind_Speed_kmh']  

Color=['red','blue','green','yellow','orange']
plt.pie(y,labels=x,startangle=90,colors=Color,explode=[0,0.5,0,0,0])
plt.title('Pie Chart with explode blue slice ')

plt.show()

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Wind_Speed_kmh']  

Color=['red','blue','green','yellow','orange']
plt.pie(y,labels=x,startangle=90,colors=Color,explode=[0.2,0.5,0,0.2,0])
plt.title('Pie Chart with explode blue,red and yellow slice ')

plt.show()

# %% [markdown]
# ## 4. Add percentage labels to slices

# %%
df1=df[20:25]
df2=df[25:30]

x=df1['Location']
y=df2['Wind_Speed_kmh']  

Color=['red','blue','green','yellow','orange']
plt.pie(y,labels=x,startangle=90,colors=Color,autopct='%2.1f%%')
plt.title('Pie Chart with % labels')

plt.show()
