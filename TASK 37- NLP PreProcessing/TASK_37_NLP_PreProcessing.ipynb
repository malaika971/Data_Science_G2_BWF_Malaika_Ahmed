# %% [markdown]
# > #### ***SUBMITTED BY: MALAIKA AHMED***
#
# # 🔴 ***Task 37: NLP Preprocessing***
# Go through some common text preprocessing techniques and demonstrate them by applying them to different datasets.
# ***
# ***

# %% [markdown]
#  ## <span style='color:Red'>  ***What is Natural Language Processing (NLP)*** </span>
#
# Natural Language Processing is the process of making human language understandable by computers. NLP processes natural language data using grammar rules such as syntax, morphology, semantics, pragmatics and various machine learning techniques.
#
# ![image.png](data:image/png;base64,...)
#
#
# ***

# %% [markdown]
# ## ***NLP Pipeline***
# The NLP system generally consists of four steps, which are:
#
# - Pre-processing of input data,
# - Creating a language model,
# - Evaluating the results, and
# - Outputting the results.
#
# In the pre-processing step, the data is cleaned, normalized and vectorized. In the language model creation stage, pre-trained models or data sets can be used. In the results evaluation stage, the model is trained and adjusted for accurate results. In the final stage, the outputs are processed and presented to end-users.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***
# ## <span style='color:Red'>  ***What is Natural Language Processing (NLP) Used For?*** </span>
#
# NLP is used for a wide variety of language-related tasks, including answering questions, classifying text in a variety of ways, and conversing with users.
#
# ## ***Sentiment Analysis***
#
# - ***Sentiment analysis*** is the process of classifying the emotional intent of text. Generally, the input to a sentiment classification model is a piece of text, and the output is the probability that the sentiment expressed is positive, negative, or neutral.
#
#
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
#
#
# ***
#
# ## ***Named Entity Recognition***
#
#
#   - ***Named entity recognition*** aims to extract entities in a piece of text into predefined categories such as personal names, organizations, locations, and quantities. The input to such a model is generally text, and the output is the various named entities along with their start and end positions. Named entity recognition is useful in applications such as summarizing news articles and combating disinformation.
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# ***
#
# ## ***Information Retrieval***
#
# - ***Information retrieval*** finds the documents that are most relevant to a query. This is a problem every search and recommendation system faces. The goal is not to answer a particular query but to retrieve, from a collection of documents that may be numbered in the millions, a set that is most relevant to the query. Document retrieval systems mainly execute two processes: indexing and matching.In most modern systems, indexing is done by a vector space model through Two-Tower Networks, while matching is done using similarity or distance scores. Google recently integrated its search function with a multimodal information retrieval model that works with text, image, and video data.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ***
#
#   ## ***Chat Box***
#
#   - ***Chatbots*** NLP technology is used in the development of chatbots that interact with people. Chatbots are used for customer service and sales activities in many sectors. For example, many brands in the market, big or small, benefit from this technology. The WhatsApp support lines used by stores such as H&M, Trendyol, Sephora, etc. are chatbots rather than people who are contacted in the question-answer or product return stages.
#
# ***

# %% [markdown]
# ## ***Summarization***
#
# - ***Summarization***: NLP technology can be used to summarize large texts and extract keywords or sentences. This technology is also used in summary techniques used in newspapers and magazines. As an example, SummarizeBot, IBM Watson and OpenAI company’s Chat GPT-3 and GPT-4 versions can be given. These tools are designed to use NLP technology to summarize documents of different types such as emails, web pages, and other texts and to perform more comprehensive operations and are offered to users.
#
#
# ## ***Speech Recognition***
#
# - ***Speech Recognition:*** Speech recognition technology uses NLP technology to convert spoken data from audio files into text. This technology is used in automatic dictators, virtual assistants, language learning applications, and many other areas. Virtual assistants such as Siri, Amazon Alexa, and Google Home are among the best examples of this technology. Users can perform a variety of tasks with voice commands such as playing music, adding a calendar event, or getting a weather report in a very short time.
#
#   ***
#   ***
#   ***

# %% [markdown]
#  # <span style='color:Red'>  ***Text preprocessing*** </span>
#
# Text preprocessing refers to a series of techniques used to clean, transform and prepare raw textual data into a format that is suitable for NLP or ML tasks. The goal of text preprocessing is to enhance the quality and usability of the text data for subsequent analysis or modeling
# Here is a  list of common techniques and steps involved in text preprocessing:
#
# - Text lowercasing
# - Tokenization
# - Stop-word removal
# - Handling Numerical values
# - Handling Special characters
# - Whitespace stripping
# - Lemmatization/Stemming
# - Spelling correction
# - Part-of -Speech tagging
# - Handling Contractions
# - Removal of short/rare words

# %% [markdown]
# ***

# %% [markdown]
# # ***Applying different Text-Preprocessing Techniques on dataset****

# %% [markdown]
#  ## <span style='color:Blue'>  ***1. Lowercasing*** </span>
#
# Lowercasing is a text preprocessing step where all letters in the text are converted to lowercase. This step is implemented so that the algorithm does not treat the same words differently in different situations.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/IMDB Dataset.csv')

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 418

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['review'] = df['review'].str.lower()

# %%
df['review'].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production. <br /><br />the...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically there's a family where a little boy ...
# 4    petter mattei's "love in the time of money" is...
# Name: review, dtype: object

# %% [markdown]
# ***
# ***
#  ## <span style='color:Blue'>  ***2. Removing Punctuation & Special Characters*** </span>
#
# - Punctuation removal is a text preprocessing step where you remove all punctuation marks (such as periods, commas, exclamation marks, emojis etc.) from the text to simplify it and focus on the words themselves.
# - In Handling special characters and punctuation,typically we may choose to remove them or replace them with a space, depending on your specific requirements.

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# #### These are the characters which python consider as punctuations

# %%
exclude = string.punctuation

# %% [markdown]
# ### ***Creating a function to remove punctuations from text***

# %%
# str.maketrans('', '', exclude) creates a plan or a "map" that tells Python which characters to remove.
# The first two '' (empty strings) mean we’re not changing any characters to something else.
# The exclude part is telling Python, "Remove these characters.
# text.translate(...) uses the map to remove the unwanted characters from the text.


def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ### ***Applying the function on review column of dataset***

# %%
df['review'] = df['review'].apply(remove_punc1)

# %%
df['review'].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production br br the filmin...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically theres a family where a little boy j...
# 4    petter matteis love in the time of money is a ...
# Name: review, dtype: object

# %% [markdown]
# ***
# ***
#  ## <span style='color:Blue'>  ***3. Removal of HTML Tags*** </span>
#
# Removal of HTML Tags is a text preprocessing step used to clean text data from HTML documents. When working with text data obtained from web pages or other HTML-formatted sources, the text may contain HTML tags, which are not desirable for text analysis or machine learning models. Therefore, it’s important to remove HTML tags from the text data.

# %% [markdown]
# ***
# ### ***Importing re***

# %% [markdown]
# ***re is "regular expressions," which is a powerful tool in Python for matching patterns in text.This module helps to find and manipulate patterns, such as removing specific types of characters or strings from a text.***

# %%
import re

# %% [markdown]
# ### ***Creating function to remove html tags***

# %%
# re.compile('<.*?>') creates a regular expression pattern to match anything that looks like an HTML tag.
# pattern.sub(r'', text) uses the pattern created in the previous step to search for all occurrences of HTML tags in text.
# sub() is a method that substitutes (replaces) parts of the text that match the pattern.
# r'' means "replace with an empty string," effectively removing the HTML tags.
# So, any text that matches the pattern (i.e., any HTML tag) will be replaced by nothing, effectively removing it from the text.

def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %% [markdown]
# ### ***Applying the function on review column of dataset***

# %%
df['review'] = df['review'].apply(remove_html_tags)

# %%
df['review'].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production br br the filmin...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically theres a family where a little boy j...
# 4    petter matteis love in the time of money is a ...
# Name: review, dtype: object

# %% [markdown]
# ***
# ***
#  ## <span style='color:Blue'>  ***4. Removal of URLs*** </span>
#
# When building a model, URLs are typically not relevant and can be removed from the text data.

# %% [markdown]
# ### ***Creating function to remove html tags***

# %%
# re.compile(): This function compiles a regular expression pattern into a regex object, which can be used to match strings.
# r'https?://\S+|www\.\S+': This is the regular expression pattern used to match URLs
# sub() is a method that replaces all occurrences of the pattern found in text with a specified replacement.
# r'': This is an empty string. By replacing the matched URLs with an empty string, they are effectively removed from the text.

def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
text1 = 'Check out my notebook https://www.kaggle.com/campusx/notebook8223fc1abb'
text2 = 'Check out my notebook http://www.kaggle.com/campusx/notebook8223fc1abb'
text3 = 'Google search here www.google.com'
text4 = 'For notebook click https://www.kaggle.com/campusx/notebook8223fc1abb to search check www.google.com'

# %% [markdown]
# ### ***Applying the function on texts created above***

# %%
remove_url(text1)
# Out:
# 'Check out my notebook '

# %%
remove_url(text2)
# Out:
# 'Check out my notebook '

# %%
remove_url(text3)
# Out:
# 'Google search here '

# %%
remove_url(text4)
# Out:
# 'For notebook click  to search check '

# %% [markdown]
# ***
# ***
#  ## <span style='color:Blue'>  ***5. Handling Spelling Mistakes*** </span>

# %%
# TextBlob is used for various text processing tasks, including spelling correction.
from textblob import TextBlob

# %%
incorrect_text = 'I amm ussing Jupyterr Notebook for compleetion of Taskk 37'
textBlb = TextBlob(incorrect_text)
print("Incorrect Text: \n", incorrect_text)
# Out:
# Incorrect Text:
#  I amm ussing Jupyterr Notebook for compleetion of Taskk 37

# %%
# textBlb.correct() creates a new TextBlob object with spelling corrections applied.
# str(textBlb.correct()) converts the corrected TextBlob object back to a string.

corrected_text = str(textBlb.correct())

# %%
print("Correct Text after preprocessing: \n",corrected_text)
# Out:
# Correct Text after preprocessing:
#  I am using Jupyterr Notebook for completion of Ask 37

# %% [markdown]
# ***
# ***
#  ## <span style='color:Blue'>  ***6. Removing Stop Words*** </span>
# - Stopwords refer to the most commonly occurring words in any natural language.
# - For the purpose of analyzing text data and building NLP models, these stopwords might not add much value to the meaning of the document. Therefore, removing stopwords can help us to focus on the most important information in the text and improve the accuracy of our analysis.
# - One of the advantages of removing stopwords is that it can reduce the size of the dataset, which in turn reduces the training time required for natural language processing models.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***
# - import nltk: Imports the Natural Language Toolkit (NLTK) library, which provides tools for working with human language data.
# - nltk.download('stopwords'): Downloads the stopwords dataset from NLTK. Stopwords are common words (e.g., "and", "the", "in") that are often removed from text during preprocessing.

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# - new_text = []: Initializes an empty list new_text to store the words that are not stopwords.
#
# - for word in text.split(): Splits the input text into individual words and iterates over each word.
#
# - if word in stopwords.words('english'):: Checks if the current word is in the list of English stopwords.
#
# - stopwords.words('english'): Retrieves the list of English stopwords from NLTK.
#
# - new_text.append(''): If the word is a stopword, append an empty string to new_text. This effectively removes the stopword from the resulting text.
#
# - else: new_text.append(word): If the word is not a stopword, append it to new_text.
#
# - x = new_text[:]: Creates a copy of new_text and assigns it to x. This is done to preserve the original list.
#
# - new_text.clear(): Clears the new_text list. This is unnecessary since the list new_text is not used after this point.
#
# - return " ".join(x): Joins the words in x into a single string with spaces in between, effectively reconstructing the text without stopwords.

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production br br the filmin...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %%
df['review'][2]
# Out:
# 'i thought this was a wonderful way to spend time on a too hot summer weekend sitting in the air conditioned theater and watching a lighthearted comedy the plot is simplistic but the dialogue is witty and the characters are likable even the well bread suspected serial killer while some may be disappointed when they realize this is not match point 2 risk addiction i thought it was proof that woody allen is still fully in control of the style many of us have grown to lovebr br this was the most id laughed at one of woodys comedies in years dare i say a decade while ive never been impressed with scarlet johanson in this she managed to tone down her sexy image and jumped right into a average but spirited young womanbr br this may not be the crown jewel of his career but it was wittier than devil wears prada and more interesting than superman a great comedy to go see with friends'

# %% [markdown]
# ### ***Applying the Function***

# %%
remove_stopwords(df['review'][2])
# Out:
# ' thought    wonderful way  spend time    hot summer weekend sitting   air conditioned theater  watching  lighthearted comedy  plot  simplistic   dialogue  witty   characters  likable even  well bread suspected serial killer   may  disappointed   realize    match point 2 risk addiction  thought   proof  woody allen  still fully  control   style many  us  grown  lovebr br     id laughed  one  woodys comedies  years dare  say  decade  ive never  impressed  scarlet johanson    managed  tone   sexy image  jumped right   average  spirited young womanbr br  may    crown jewel   career    wittier  devil wears prada   interesting  superman  great comedy  go see  friends'

# %% [markdown]
# ***
# ***
# ## <span style='color:Blue'>  ***7. Removing Emojis*** </span>

# %%
# !pip install emoji

# %%
import emoji

# %%
print(emoji.demojize('Bytewise DataScience fellowship is 🔥'))
# Out:
# Bytewise DataScience fellowship is :fire:

# %% [markdown]
# ***
# ***
# ## <span style='color:Blue'>  ***8. Tokenization*** </span>
# Tokenization is the process of breaking down large blocks of text such as paragraphs and sentences into smaller, more manageable units.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***Tokenization using the split function***

# %%
# word tokenization
sent1 = 'I am pursing Ms in A.I. from NUST'
sent2 = "you may email me at ma@gmail.com"
sent3 = 'I travel 5km to university'

# %%
print("Word Tokenization of Sentence 1 using Split Function: \n", sent1.split())
# Out:
# Word Tokenization of Sentence 1 using Split Function:
#  ['I', 'am', 'pursing', 'Ms', 'in', 'A.I.', 'from', 'NUST']

# %%
print("Word Tokenization of Sentence 2 using Split Function: \n", sent2.split())
# Out:
# Word Tokenization of Sentence 2 using Split Function:
#  ['you', 'may', 'email', 'me', 'at', 'ma@gmail.com']

# %%
print("Word Tokenization of Sentence 3 using Split Function: \n", sent3.split())
# Out:
# Word Tokenization of Sentence 3 using Split Function:
#  ['I', 'travel', '5km', 'to', 'university']

# %%
#sentence tokenization
Para='Natural Language Processing (NLP) is tough!! .However,i love learning its concepts.Also i am enjoying working on Task 37'
print("Sentence tokenization using split function: \n", Para.split('.'))
# Out:
# Sentence tokenization using split function:
#  ['Natural Language Processing (NLP) is tough!! ', 'However,i love learning its concepts', 'Also i am enjoying working on Task 37']

# %% [markdown]
# ## ***INSIGHTS***
#
# - The split() function simply breaks the sentence by spaces. It doesn't handle punctuation or special characters well.
# - Words with punctuation marks (like A.I.) and email addresses are not properly separated.
# - The function does not recognize sentence boundaries when tokenizing sentences, resulting in inaccurate splitting.
# ***

# %% [markdown]
# ## ***Tokenization using the NLTK***

# %%
 from nltk.tokenize import word_tokenize,sent_tokenize

# %%
print("Word Tokenization of Sentence 1 using NLTK Function: \n", word_tokenize(sent1))
# Out:
# Word Tokenization of Sentence 1 using NLTK Function:
#  ['I', 'am', 'pursing', 'Ms', 'in', 'A.I', '.', 'from', 'NUST']

# %%
print("Word Tokenization of Sentence 2 using NLTK Function: \n", word_tokenize(sent2))
# Out:
# Word Tokenization of Sentence 2 using NLTK Function:
#  ['you', 'may', 'email', 'me', 'at', 'ma', '@', 'gmail.com']

# %%
print("Word Tokenization of Sentence 3 using NLTK Function: \n", word_tokenize(sent3))
# Out:
# Word Tokenization of Sentence 3 using NLTK Function:
#  ['I', 'travel', '5km', 'to', 'university']

# %%
print("Sentence Tokenization using NLTK Function: \n", sent_tokenize(Para))
# Out:
# Sentence Tokenization using NLTK Function:
#  ['Natural Language Processing (NLP) is tough!!', '.However,i love learning its concepts.Also i am enjoying working on Task 37']

# %% [markdown]
# ## ***INSIGHTS***
# - NLTK's word_tokenize() function accurately separates punctuation marks from words (e.g., A.I. is split into A.I and .).
# - It breaks down email addresses incorrectly, separating @ and the domain.
# - NLTK does a better job than the split() function in recognizing punctuation as separate tokens.
# ***

# %% [markdown]
# ## ***Tokenization using the Spacy***

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent1)
doc2 = nlp(sent2)
doc3 = nlp(sent3)

# %%
for token in doc1:
    print(token)
# Out:
# I
# am
# pursing
# Ms
# in
# A.I.
# from
# NUST

# %%
for token in doc2:
    print(token)
# Out:
# you
# may
# email
# me
# at
# ma@gmail.com

# %%
for token in doc3:
    print(token)
# Out:
# I
# travel
# 5
# km
# to
# university

# %% [markdown]
# ## ***INSIGHTS***
# - spaCy handles punctuation well, keeping A.I. as one token, which might be more appropriate in certain contexts.
# - spaCy treats numbers (e.g., 5km) more intelligently by splitting them into separate tokens (5, km).
# - Email addresses remain intact, making spaCy more accurate in maintaining certain token integrity.

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## <span style='color:Blue'>  ***9. Stemming and Lemmatization*** </span>
#
#
# Stemming involves reducing words to their root form, while lemmatization reduces them to their base or dictionary form. Both processes aim to unify different word forms to streamline text analysis by treating variations of words as a single entity, facilitating more accurate and efficient language processing.
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***Stemming***

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Initialize the PorterStemmer
stemmer = PorterStemmer()

# Example sentences
sentences = [
    'I am pursuing MS in A.I. from NUST',
    "You may email me at ma@gmail.com",
    'I travel 5km to university'
]

# %%
# Function to perform stemming
def stem_sentences(sentences):
    for sentence in sentences:
        print(f"\nOriginal Sentence: {sentence}")

        # Tokenize the sentence into words
        tokens = word_tokenize(sentence)

        # Apply stemming to each word
        stemmed_words = [stemmer.stem(word) for word in tokens]

        # Join the stemmed words back into a sentence
        stemmed_sentence = ' '.join(stemmed_words)
        print(f"Stemmed Sentence: {stemmed_sentence}")

# Call the function
stem_sentences(sentences)
# Out:
# Original Sentence: I am pursuing MS in A.I. from NUST
# Stemmed Sentence: i am pursu ms in a.i . from nust
#
# Original Sentence: You may email me at ma@gmail.com
# Stemmed Sentence: you may email me at ma @ gmail.com
#
# Original Sentence: I travel 5km to university
# Stemmed Sentence: i travel 5km to univers

# %% [markdown]
# ***
# ## ***Lemmatization***

# %%
import spacy

# Load the spaCy model for lemmatization
nlp = spacy.load("en_core_web_sm")

# %%
# Example sentences
sentences = [
    'I am pursuing MS in A.I. from NUST',
    "You may email me at ma@gmail.com",
    'I travel 5km to university'
]

# %%
# Function to perform lemmatization
def lemmatize_sentences(sentences):
    for sentence in sentences:
        print(f"\nOriginal Sentence: {sentence}")

        # Process the sentence using spaCy's NLP model
        doc = nlp(sentence)

        # Extract the lemma (base form) for each word in the sentence
        lemmatized_words = [token.lemma_ for token in doc]
        print(f"Lemmatized Words: {lemmatized_words}")

# Call the function
lemmatize_sentences(sentences)
# Out:
# Original Sentence: I am pursuing MS in A.I. from NUST
# Lemmatized Words: ['I', 'be', 'pursue', 'MS', 'in', 'A.I.', 'from', 'NUST']
#
# Original Sentence: You may email me at ma@gmail.com
# Lemmatized Words: ['you', 'may', 'email', 'I', 'at', 'ma@gmail.com']
#
# Original Sentence: I travel 5km to university
# Lemmatized Words: ['I', 'travel', '5', 'km', 'to', 'university']

# %% [markdown]
# ***
# ***
# ## <span style='color:Blue'>  ***10. Removing Numbers*** </span>
#
#
# This methodology eliminates numerical values that may not be relevant.And, reduces the number of unique tokens and focuses on textual data.

# %%
import pandas as pd

# Detecting reviews containing digits
df['contains_digits'] = df['review'].str.contains(r'\d+', regex=True)

# Filtering reviews with digits
reviews_with_digits = df[df['contains_digits'] == True]

print(reviews_with_digits)
# Out:
#                                                   review sentiment  \
# 0      one of the other reviewers has mentioned that ...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically theres a family where a little boy j...  negative
# 5      probably my alltime favorite movie a story of ...  positive
# 6      i sure would like to see a resurrection of a u...  positive
# ...                                                  ...       ...
# 49990  lame lame lame a 90minute cringefest thats 89 ...  negative
# 49993  robert colomb has two fulltime jobs hes known ...  negative
# 49994  this is your typical junk comedybr br there ar...  negative
# 49995  i thought this movie did a down right good job...  positive
# 49998  im going to have to disagree with the previous...  negative
#
#        contains_digits
# 0                 True
# 2                 True
# 3                 True
# 5                 True
# 6                 True
# ...

# %%
import re

def remove_digits(text):
    return re.sub(r'\d+', '', text)
df['cleaned_review'] = df['review'].apply(remove_digits)

# %%
df['cleaned_review'][49990]
# Out:
# 'lame lame lame a minute cringefest thats  minutes too long a setting ripe with atmosphere and possibility an abandoned convent is squandered by a stinker of a script filled with clunky witless dialogue thats straining ohsohard to be hip mostly its just embarrassing and the attempts at gonzo horror fall flat a sample of this movies dialogue after demonstrating her artillery fast dolly shot to a closeup of barbeaus vigilante character\x85she any questions hyuck hyuck hyuck bad acting idiotic homophobic jokes and judging from the creature effects it looks like the directors watched the evil dead way too many times br br i owe my friends big time for renting this turkey and subjecting them to ninety wasted minutes theyll never get back what a turd'

# %% [markdown]
# ***
