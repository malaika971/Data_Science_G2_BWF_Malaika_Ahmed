# %% [markdown]
# # 🔴 Task 12: Introduction to Pandas (Series, DataFrame basics)

# %% [markdown]
# ### 1.Create a Pandas Series from a Python list, numpy array, and a dictionary.

# %%
import numpy as np
import pandas as pd 

list1=[1,2,3,4]
list2=[5,6,7,8]
array1=np.array(list2)
dictionary1={
             'Name':['Malaika','Saman','Sidrah','Tayebah'],
             'University':["NUST","LUMS","GIKI","FAST"],
             'Home town':["Quetta","Peshawar","Karachi","Lahore"]
             }

print("Python list :",list1,"\n")
print("Numpy array",array1,"\n")
print("Dictionary",dictionary1,"\n")

pseries1=pd.Series(list1)
pseries2=pd.Series(array1)
pseries3=pd.Series(dictionary1)

print("Panda series from python list\n",pseries1,"\n")
print("Panda series from Numpy Array\n",pseries2,"\n")
print("Panda series from Dictionary\n", pseries3,"\n")
# Out:
# Python list : [1, 2, 3, 4]
#
# Numpy array [5 6 7 8]
#
# Dictionary {'Name': ['Malaika', 'Saman', 'Sidrah', 'Tayebah'], 'University': ['NUST', 'LUMS', 'GIKI', 'FAST'], 'Home town': ['Quetta', 'Peshawar', 'Karachi', 'Lahore']}
#
# Panda series from python list
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# Panda series from Numpy Array
#  0    5
# 1    6
# 2    7
# 3    8
# dtype: int32
#
# Panda series from Dictionary
#  Name            [Malaika, Saman, Sidrah, Tayebah]
# University               [NUST, LUMS, GIKI, FAST]
# Home town     [Quetta, Peshawar, Karachi, Lahore]
# dtype: object

# %% [markdown]
# ### 2. Assign a custom index to the Series.

# %%
custom_index=['a','b','c','d']
pseries1.index=custom_index
print("Series with custom indexing :\n",pseries1)
# Out:
# Series with custom indexing :
#  a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# ### 3. Perform basic arithmetic operations on Series.

# %%
list1=[1,2,3,4]
list2=[5,6,7,8]
array1=np.array(list2)
dictionary1={
             'Name':['Malaika','Saman','Sidrah','Tayebah'],
             'University':["NUST","LUMS","GIKI","FAST"],
             'Home town':["Quetta","Peshawar","Karachi","Lahore"]
             }

pseries1=pd.Series(list1)
pseries2=pd.Series(array1)
pseries3=pd.Series(dictionary1)
sum=pseries1+pseries2
print("Sum of the two pandas series is: \n", sum,"\n")

subtract=pseries2-pseries1
print("Subtraction of the two pandas series is: \n",subtract,"\n")

product=pseries1*pseries2
print("Product of the two pandas series is: \n", product,"\n")

divide=pseries2/pseries1
print("Division of the two pandas series is: \n", divide,"\n")
# Out:
# Sum of the two pandas series is:
#  0     6
# 1     8
# 2    10
# 3    12
# dtype: int64
#
# Subtraction of the two pandas series is:
#  0    4
# 1    4
# 2    4
# 3    4
# dtype: int64
#
# Product of the two pandas series is:
#  0     5
# 1    12
# 2    21
# 3    32
# dtype: int64
#
# Division of the two pandas series is:
#  0    5.000000
# 1    3.000000
# 2    2.333333
# 3    2.000000
# dtype: float64

# %% [markdown]
# ### 4.Access elements using index labels and positions.

# %%
print(" Series 1\n",pseries1)
custom_index=['a','b','c','d']
print("\n")
pseries1.index=custom_index
print("Series1 wit custom indexing\n:",pseries1)
access=pseries1.loc['c']
print("\n")
print("Accessing third element of pandas series #01 using index label:",access)
access1=pseries1.iloc[2]
print("Accessing third element of pandas series #01 using position :",access1)
# Out:
#  Series 1
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
#
# Series1 wit custom indexing
# : a    1
# b    2
# c    3
# d    4
# dtype: int64
#
#
# Accessing third element of pandas series #01 using index label: 3
# Accessing third element of pandas series #01 using position : 3

# %% [markdown]
# ### 5.Filter the Series to include only values greater than a specific threshold.

# %%
print(pseries1)
filtered_series = pseries1[pseries1 > 2]
print("\n")
print("Series with values greater than 2\n",filtered_series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
#
#
# Series with values greater than 2
#  c    3
# d    4
# dtype: int64

# %% [markdown]
# ### 6. Create a DataFrame from a dictionary of lists.

# %%
print("Dictionary of lists\n",dictionary1)
print("\n")
df1=pd.DataFrame(dictionary1)
print("DATA FRAME FROM DICTIONARY\n:",df1)
# Out:
# Dictionary of lists
#  {'Name': ['Malaika', 'Saman', 'Sidrah', 'Tayebah'], 'University': ['NUST', 'LUMS', 'GIKI', 'FAST'], 'Home town': ['Quetta', 'Peshawar', 'Karachi', 'Lahore']}
#
#
# DATA FRAME FROM DICTIONARY
# :       Name University Home town
# 0  Malaika       NUST    Quetta
# 1    Saman       LUMS  Peshawar
# 2   Sidrah       GIKI   Karachi
# 3  Tayebah       FAST    Lahore

# %% [markdown]
# ### 7.Create a DataFrame from a numpy array, specifying column and index names.

# %%
array1=np.array([['Malaika','Mahjabeen','Fatimah'],[23,22,21],[1,3,5]])
print(array1)
columns = ['1', '2', '3']
index = ['Name', 'Age', 'Semester']
pd.DataFrame(array1,columns=columns,index=index)
# Out:
# [['Malaika' 'Mahjabeen' 'Fatimah']
#  ['23' '22' '21']
#  ['1' '3' '5']]
#                 1          2        3
# Name      Malaika  Mahjabeen  Fatimah
# Age            23         22       21
# Semester        1          3        5

# %% [markdown]
# ### 8. Load a DataFrame from a CSV file.

# %%
pd.read_csv('Desktop/TASK#12_BWF_Malaika/Fortune 500 2017 - Fortune 500.csv')
# Out:
#      Rank               Title                           Website  Employees  \
# 0       1             Walmart            http://www.walmart.com    2300000
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2       3               Apple              http://www.apple.com     116000
# 3       4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4       5            McKesson           http://www.mckesson.com      68000
# ..    ...                 ...                               ...        ...
# 495   496       Michaels Cos.           http://www.michaels.com      31000
# 496   497       Toll Brothers       http://www.tollbrothers.com       4200
# 497   498               Yahoo              http://www.yahoo.com       8500
# 498   499       Vistra Energy       http://www.vistraenergy.com       4431
# 499   500      ABM Industries                http://www.abm.com     110000
#
# ...

# %%
company=pd.read_csv('Desktop/TASK#12_BWF_Malaika/Fortune 500 2017 - Fortune 500.csv')

# %% [markdown]
# ### 9.Display the first and last five rows of the DataFrame.

# %%
company.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
company.tail()
# Out:
#      Rank           Title                      Website  Employees  \
# 495   496   Michaels Cos.      http://www.michaels.com      31000
# 496   497   Toll Brothers  http://www.tollbrothers.com       4200
# 497   498           Yahoo         http://www.yahoo.com       8500
# 498   499   Vistra Energy  http://www.vistraenergy.com       4431
# 499   500  ABM Industries           http://www.abm.com     110000
#
#                          Sector                          Industry  \
# 495                   Retailing        Specialty Retailers: Other
# 496  Engineering & Construction                      Homebuilders
# 497                  Technology   Internet Services and Retailing
# 498                      Energy                            Energy
# 499           Business Services  Diversified Outsourcing Services
#
#         Hqlocation                Hqaddr     Hqcity Hqstate  ...  \
# 495     Irving, TX  8000 Bent Branch Dr.     Irving      TX  ...
# ...

# %% [markdown]
# ### 10.Get a summary of the DataFrame including the mean, median, and standard deviation of numeric columns

# %%
company.describe()
# Out:
#              Rank     Employees         Hqzip       Revenues  Revchange  \
# count  500.000000  5.000000e+02    500.000000     500.000000  500.00000
# mean   250.492000  5.635013e+04  46791.714000   24111.748000    3.75800
# std    144.477366  1.234520e+05  30160.384765   38337.353337   19.96748
# min      1.000000  8.300000e+01   1104.000000    5145.000000  -57.50000
# 25%    125.750000  1.190000e+04  19099.000000    7245.000000   -3.82500
# 50%    250.500000  2.500000e+04  46244.500000   11384.000000    1.90000
# 75%    375.250000  5.682525e+04  75045.000000   22605.250000    7.32500
# max    500.000000  2.300000e+06  98188.000000  485873.000000  197.30000
#
#             Profits        Assets  Totshequity
# count    500.000000  5.000000e+02     500.0000
# mean    1779.479800  8.038934e+04   13640.1470
# std     3937.558721  2.704257e+05   30523.1538
# min    -6177.000000  4.370000e+02  -12688.0000
# 25%      235.725000  8.436500e+03    1997.5000
# ...

# %% [markdown]
# ### 11.Extract a specific column as a Series.

# %%
company['Industry']
# Out:
# 0                         General Merchandisers
# 1      Insurance: Property and Casualty (Stock)
# 2                   Computers, Office Equipment
# 3                            Petroleum Refining
# 4                      Wholesalers: Health Care
#                          ...
# 495                  Specialty Retailers: Other
# 496                                Homebuilders
# 497             Internet Services and Retailing
# 498                                      Energy
# 499            Diversified Outsourcing Services
# Name: Industry, Length: 500, dtype: object

# %% [markdown]
# ### 12.Filter rows based on column values.

# %%
energy_companies = company.loc[company['Industry'] == 'Energy']
print(energy_companies)
# Out:
#      Rank                Title                           Website  Employees  \
# 102   103  World Fuel Services            http://www.wfscorp.com       5000
# 228   229           NRG Energy                http://www.nrg.com       8763
# 236   237  NGL Energy Partners  http://www.nglenergypartners.com       3200
# 366   367             Williams           http://www.williams.com       5604
# 399   400              Calpine            http://www.calpine.com       2372
# 456   457                  UGI            http://www.ugicorp.com      13105
# 498   499        Vistra Energy       http://www.vistraenergy.com       4431
#
#      Sector Industry           Hqlocation               Hqaddr  \
# 102  Energy   Energy            Miami, FL   9800 N.W. 41st St.
# 228  Energy   Energy        Princeton, NJ  804 Carnegie Center
# 236  Energy   Energy            Tulsa, OK    6120 S. Yale Ave.
# 366  Energy   Energy            Tulsa, OK    1 Williams Center
# ...

# %% [markdown]
# ### 14.Add a new column to the DataFrame.

# %%
company['Employees_Left']=10
company
# Out:
#      Rank               Title                           Website  Employees  \
# 0       1             Walmart            http://www.walmart.com    2300000
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2       3               Apple              http://www.apple.com     116000
# 3       4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4       5            McKesson           http://www.mckesson.com      68000
# ..    ...                 ...                               ...        ...
# 495   496       Michaels Cos.           http://www.michaels.com      31000
# 496   497       Toll Brothers       http://www.tollbrothers.com       4200
# 497   498               Yahoo              http://www.yahoo.com       8500
# 498   499       Vistra Energy       http://www.vistraenergy.com       4431
# 499   500      ABM Industries                http://www.abm.com     110000
#
# ...

# %% [markdown]
# ### 15.Delete a column from the DataFrame.

# %%
del company['Employees_Left']

# %% [markdown]
# ### 16 Rename columns in the DataFrame.

# %%
company=company.rename(columns={'Employees':'Total_Employees'})
company
# Out:
#      Rank               Title                           Website  \
# 0       1             Walmart            http://www.walmart.com
# 1       2  Berkshire Hathaway  http://www.berkshirehathaway.com
# 2       3               Apple              http://www.apple.com
# 3       4         Exxon Mobil         http://www.exxonmobil.com
# 4       5            McKesson           http://www.mckesson.com
# ..    ...                 ...                               ...
# 495   496       Michaels Cos.           http://www.michaels.com
# 496   497       Toll Brothers       http://www.tollbrothers.com
# 497   498               Yahoo              http://www.yahoo.com
# 498   499       Vistra Energy       http://www.vistraenergy.com
# 499   500      ABM Industries                http://www.abm.com
#
#      Total_Employees                      Sector  \
# 0            2300000                   Retailing
# 1             367700                  Financials
# ...
