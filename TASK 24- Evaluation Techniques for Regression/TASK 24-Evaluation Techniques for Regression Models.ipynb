# %%
# EFFICIENCY OF REGRESSION

# %% [markdown]
# > ### ***Submitted By: Malaika Ahmed***
#
# # 🔴 **Task 24: Evaluation Techniques for Regression Models**
# Evaluation techniques for regression models are crucial for assessing their performance. Common metrics include Mean Absolute Error (MAE), which measures the average magnitude of errors, and Mean Squared Error (MSE), which emphasizes larger errors due to squaring the differences. Root Mean Squared Error (RMSE) provides error estimates in the same unit as the target variable. R-squared (R²) indicates the proportion of variance explained by the model, while Adjusted R-squared accounts for the number of predictors. Mean Absolute Percentage Error (MAPE) offers a percentage-based accuracy metric, and Median Absolute Error provides a robust measure of central tendency for errors, less influenced by outliers. These metrics help in comparing and refining regression models.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'> ***First, creating Linear Regression Model*** </span>

# %%
# Importing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import mean_absolute_percentage_error, median_absolute_error

# %% [markdown]
# ### ***Importing Data Set***

# %%
df = pd.read_csv('pckg.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# ### ***Creating Scatter plot between cgpa and package***

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# ### ***Separating Input and Target columns***

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %% [markdown]
# ### ***Splitting Data into training and testing***

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### ***Defining an object for linearRegression***

# %%
lr = LinearRegression()

# %% [markdown]
# ### ***Fitting/Training the Linear Regression model***

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'],color='g')

plt.plot(X_train,lr.predict(X_train),color='red')

plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'> ***Evaluation Metrics for Regression Problems*** </span>

# %% [markdown]
#  ##  <span style='color:Blue'> ***1. Mean Absolute Error (MAE)*** </span>
#  The MAE is simply defined as the sum of all the distances/residual s(the difference between the actual and predicted value) divided by the total number of points in the dataset.
# It is the absolute average distance of our model predictn. Mean absolute error (MAE) is a measure of errors between paired observations expressing the same phenomenon. Examples of Y versus X include comparisons of predicted versus observed, subsequent time versus initial time, and one technique of measurement versus an alternative technique of measurement. In simple Words, it is Average of the absolute differences between predicted and actual values.
#
#
#
#
#
#  n![image.png](attachment:d2d3e20c-8b2e-49ac-b9a9-5b0de8f19a3d.png)
#
# It is thus an arithmetic average of the absolute errors, where yi is the prediction and xi the actual value
#
#
#
#
# ![image.png](attachment:65f9e7ae-c142-4cdf-bef0-21df5c792c2b.png)
#
# .

# %% [markdown]
# ### ***Advantages***
#
# - It has the same unit as the target variable of original data.
# - Robust to Outliers( it can handly outliers relatively better)
#
# ### ***Limitations***
#
# - Graph of modulus function is not differentiable at zero.Which leads to absolute error.To solve this,we use Mean Squared Error.

# %% [markdown]
# ### ***When to Use MAE***
#
# - If we want to know the model’s average absolute distance when making a prediction, we can use MAE. In other words, we want to know how close the predictions are to the actual model on average.
# - Since its robust to outliers,so if out data has more outliers,its good to use MAE.
# - L low MAE values indicate that the model is correctly predicting
# - . Larger MAE values indicate that the model is poor at prediction

# %% [markdown]
# ## ***Calculating MAE***

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %% [markdown]
# ## ***Insights from MAE***
#
# The Mean Absolute Error (MAE) of our model is 0.288, which is a bit low given the target variable range of 0 to 40. This indicates that, on average, our model's predictions deviate from the actual values by 0.28 units.This MAE tells that our model has good predictive accuracy./'

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***2. Mean Squared Error (MSE)*** </span>

# %% [markdown]
# - Mean Squared Error (MSE) or Mean Squared Deviation (MSD) of an estimator (of a procedure for estimating an unobserved quantity) measures the average of the squares of the errors — that is, the average squared difference between the estimated values and the actual value.
# - It is Average of the squared differences between predicted and actual values.
#
# - The MSE is a measure of the quality of an estimator — it is always non-negative, and values closer to zero are better.
# - Sensitive to outliers, as squaring emphasizes large errors.
#
# ![image.png](attachment:98693e98-dc1b-477a-8434-fb37cf3d8876.png)
#
#
#
# ![image.png](attachment:313a58b1-4b94-4e10-bb93-43c2b5561e77.png)
# g)

# %% [markdown]
# ### ***Advantages***
# - The graph of MSE is differentiable, so you can easily use it as a loss function.
#
# ### ***Limitations***
# - The value you get after calculating MSE is a squared unit of output. for example, the output variable is in meter(m) then after calculating MSE the output we get is in meter squared.
# - If you have outliers in the dataset then it penalizes the outliers most and the calculated MSE is bigger. So, in short, It is not Robust to outliers which were an advantage in MAE

# %% [markdown]
# ### ***When to Use MSE***
#
# - As it is  sensitive to outliers,therefore when out data has less outliers,we should use MSE.

# %% [markdown]
# ## ***Calculating MSE***

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***3. Root Mean Squared Error (RMSE)*** </span>
#
# - Root mean squared error, which is the square root of the average squared distance (difference between actual and predicted value).
# -
# RMSE is defined as the square root of all the squares of the distance divided by the total number of point
# - RMSE functions similarly to MAE (that is, you use it to determine how close the prediction is to the actual value on average), but with a minor difference.
# - e RMSis used E to determine whether there are any large errors or distances that could be caused if the model overestimated the prediction (that is the model predicted values that were significantly higher than the actual value) or underestimated the predictions (that is, predicted values less than actual prediction
#
#
#   ).s
# ![image.png](attachment:9c93665e-7bef-49a5-ab91-374cb6cbe8fa.png)
#
#
# .

# %% [markdown]
# ### ***Advantages***
# - It has the same unit as the target variable of original data.Therefore,interpretation becomes easy.
#
# ### ***Limitation***
# - Less Robust to Outliers.

# %% [markdown]
# ### ***When to Use RMSE***

# %% [markdown]
# - If you are concerned about large errors, RMSE is a good metric to use. If the model overestimated or underestimated some points in the prediction (because the residual will be square, resulting in a large error), you should use RMSE.

# %% [markdown]
# ## ***Calculating RMSE***

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***4. R2 Score*** </span>
#
# - R2 score is also called "Coefficient of Determinant" and "Goodness of Fit"
# - The R2 score (pronounced R-Squared Score) is a statistical measure that tells us how well our model is making all its predictions on a scale of zero to one.
# - We can use the R2 score to determine the accuracy of our model in terms of distance or residual.
# - Measures the proportion of variance in the dependent variable explained by the model.
# - Values closer to 1.0 indicate a better model.
#
#
# ![image.png](attachment:98ae2c34-d8e0-4188-8e58-349998ca9dde.png)
#
#
# ![image.png](attachment:36b2ec9c-ec26-40e0-9634-9a2cd0a6e433.png)
#
# ![image.png](attachment:e20679a8-0ecc-4883-a170-8e09528dca64.png)

# %% [markdown]
# ### ***Advantage***
# - Easy to interpret results.If R2 score is 1,suggests that Regression line perfectly fits the model,making no error.If R2 is zero,it suggests that Regression line is same as mean line.Input column (cgpa) is making no impact in predicting salary.Model is predicting the salary jusy by calculating average salary.Indicates poor model.
#
# ### ***Limitation***
# - Can increase artificially as you add more features, even if unnecessary.To deal with it we have adjusted R2 score

# %% [markdown]
# ## ***Calculating R2 SCORE***

# %%
print("R2 SCORE",r2_score(y_test,y_pred))
# Out:
# R2 SCORE 0.780730147510384

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***5. Adjusted R2 Score*** </span>
# - The adjusted R-squared is a modified version of R-squared that adjusts for predictors that are not significant in a regression model.
# -
# Compared to a model with additional input variables, a lower adjusted R-squared indicates that the additional input variables are not adding value to the model
# -
# Compared to a model with additional input variables, a higher adjusted R-squared indicates that the additional input variables are adding value to the mode
#
#
# ![image.png](attachment:dd5e84e6-ddb2-4ee8-961e-22554a241d90.png)
#
# ### ***When to use Adjusted R2 Score***
# When we are having more input columns/Multiple linear regression ,adjusted R2 score is good to use.It helps in predicting whether input column is relevant or irrevant. l.

# %% [markdown]
# ## ***Calculating Adjusted R2 SCORE***

# %%
X_test.shape
# Out:
# (40, 1)

# %%
r2 = r2_score(y_test,y_pred)

# %%
# n is number of observations thats 40 in our case.
# k is input columns ,in our case its 1 (cgpa)
#1 - ((1-r2)*(n-1)/(n-k-2))

ad=1 - ((1-r2)*(40-1)/(40-1-1))
print("Adjusted R2 Square value is :",ad)
# Out:
# Adjusted R2 Square value is : 0.7749598882343415

# %% [markdown]
# ## ***Insights from Adjusted R2 Score***
#
# "The Adjusted R² value of our model is approximately 0.775, indicating that 77.5% of the variance in the target variable is explained by the predictors(input features/columns) in the model. This high Adjusted R² demonstrates that the model has a strong fit and effectively captures the  relationship between the independent variables and the dependent variable. However, there is still room for improvement, as 22.5% of the variance remains unexplained."

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***6. Mean Absolute Percentage Error (MAPE)*** </span>
# - Mean absolute percentage error (MAPE) is the percentage equivalent of mean absolute error (MAE).
# - Mean absolute percentage error measures the average magnitude of error produced by a model, or how far off predictions are on average.
# - A MAPE value of 20% means that the average absolute percentage difference between the predictions and the actuals is 20%. In other words, the model’s predictions are, on average, off by 20% from the real values.
# - A lower MAPE value indicates a more accurate prediction – an MAPE of 0% means the prediction is the same as the actual.
# - While a higher MAPE value indicates a less accurate prediction.
#
#
# ![image.png](attachment:0944098f-81ee-4410-896a-e75f3dc435cd.png)
#
# ime).

# %% [markdown]
# Where:
# - N is the number of fitted points;
# - A is the actual value;
# - F is the forecast value;
# - Σ is summation notation (the absolute value is summed for every forecasted point in time).

# %% [markdown]
# ## ***Calculating Mean Absolute Percentage Error (MAPE)***

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# 0.1062335673332732

# %% [markdown]
# ***

# %% [markdown]
#  ##  <span style='color:Blue'> ***7.  Median Absolute Error*** </span>
# - The median absolute deviation(MAD) is a robust measure of how spread out a set of data is. The variance and standard deviation are also measures of spread, but they are more affected by extremely high or extremely low values and non normality. If your data is normal, the standard deviation is usually the best choice for assessing spread. However, if your data isn’t normal, the MAD is one statistic you can use instead.
# - The Interquartile Range is similar to the MAD,
# - The loss is calculated by taking the median of all absolute differences between the target and the prediction. If ŷ is the predicted value of the ith sample and yi is the corresponding true value, then the median absolute error estimated over n samples is defined as follows:
#
# ![image.png](attachment:fad961df-7dc0-4008-a5ff-3aa962dbfd3e.png)

# %% [markdown]
# ## ***Calculating Median Absolute Error***

# %%
medae = median_absolute_error(y_test, y_pred)
medae
# Out:
# 0.2516271056844266

# %% [markdown]
# ***
