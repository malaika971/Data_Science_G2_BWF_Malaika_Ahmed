# %% [markdown]
# # 🔴 Task 17: Advanced plotting techniques (subplots, histograms, box plots)
# #### Summitted by Malaika Ahmed

# %% [markdown]
# # 🟡 Subplots

# %% [markdown]
# ### 1. Generate a figure with 2x2 subplots, each containing a different type of plot (e.g., line plot, scatter plot, bar plot, and histogram).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv("Desktop/weatherdata.csv")
# Out:
#             Location        Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  1/14/2024 21:12      10.683001     41.195754
# 1          San Diego  5/17/2024 15:22       8.734140     58.319107
# 2          San Diego   5/11/2024 9:30      11.632436     38.820175
# 3       Philadelphia  2/26/2024 17:32      -8.628976     54.074474
# 4        San Antonio  4/29/2024 13:23      39.808213     72.899908
# ...              ...              ...            ...           ...
# 999915       Phoenix  4/29/2024 20:49      13.335441     39.649131
# 999916      New York  1/30/2024 15:04       1.837912     66.505813
# 999917   Los Angeles  3/27/2024 12:25      34.641340     78.108101
# 999918  Philadelphia   4/6/2024 23:13      25.456678     37.764932
# 999919        Dallas  4/20/2024 19:37      12.781843     71.636138
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# 1               9.111623       27.715161
# ...

# %%
df=pd.read_csv("Desktop/weatherdata.csv")

# %% [markdown]
# ### 🔹 Extracting little chunks of Data from df to plot 4 plots separately

# %%
df1=df['Temperature_C']
df1
# Out:
# 0         10.683001
# 1          8.734140
# 2         11.632436
# 3         -8.628976
# 4         39.808213
#             ...
# 999915    13.335441
# 999916     1.837912
# 999917    34.641340
# 999918    25.456678
# 999919    12.781843
# Name: Temperature_C, Length: 999920, dtype: float64

# %%
df2=df['Humidity_pct']
df2
# Out:
# 0         41.195754
# 1         58.319107
# 2         38.820175
# 3         54.074474
# 4         72.899908
#             ...
# 999915    39.649131
# 999916    66.505813
# 999917    78.108101
# 999918    37.764932
# 999919    71.636138
# Name: Humidity_pct, Length: 999920, dtype: float64

# %%
df3=df['Precipitation_mm']
df3
# Out:
# 0         4.020119
# 1         9.111623
# 2         4.607511
# 3         3.183720
# 4         9.598282
#             ...
# 999915    8.949140
# 999916    4.934130
# 999917    8.131816
# 999918    6.724407
# 999919    2.745614
# Name: Precipitation_mm, Length: 999920, dtype: float64

# %%
df4=df['Wind_Speed_kmh']
df4
# Out:
# 0          8.233540
# 1         27.715161
# 2         28.732951
# 3         26.367303
# 4         29.898622
#             ...
# 999915    14.625911
# 999916     4.797305
# 999917    19.607961
# 999918     0.775982
# 999919    13.026679
# Name: Wind_Speed_kmh, Length: 999920, dtype: float64

# %%
df5=df['Location']
df5
# Out:
# 0            San Diego
# 1            San Diego
# 2            San Diego
# 3         Philadelphia
# 4          San Antonio
#               ...
# 999915         Phoenix
# 999916        New York
# 999917     Los Angeles
# 999918    Philadelphia
# 999919          Dallas
# Name: Location, Length: 999920, dtype: object

# %%
x=df1[0:6]
x
# Out:
# 0    10.683001
# 1     8.734140
# 2    11.632436
# 3    -8.628976
# 4    39.808213
# 5    27.341055
# Name: Temperature_C, dtype: float64

# %%
x1=df5[0:6]
x1
# Out:
# 0       San Diego
# 1       San Diego
# 2       San Diego
# 3    Philadelphia
# 4     San Antonio
# 5       San Diego
# Name: Location, dtype: object

# %%
y1=df2[0:6]
y1
# Out:
# 0    41.195754
# 1    58.319107
# 2    38.820175
# 3    54.074474
# 4    72.899908
# 5    49.023236
# Name: Humidity_pct, dtype: float64

# %%
y2=df3[0:6]
y2
# Out:
# 0    4.020119
# 1    9.111623
# 2    4.607511
# 3    3.183720
# 4    9.598282
# 5    9.166543
# Name: Precipitation_mm, dtype: float64

# %%
y3=df4[0:6]
y3
# Out:
# 0     8.233540
# 1    27.715161
# 2    28.732951
# 3    26.367303
# 4    29.898622
# 5    27.473896
# Name: Wind_Speed_kmh, dtype: float64

# %%
y4=df1[0:6]
y4
# Out:
# 0    10.683001
# 1     8.734140
# 2    11.632436
# 3    -8.628976
# 4    39.808213
# 5    27.341055
# Name: Temperature_C, dtype: float64

# %% [markdown]
# ### 🔹 4 SUBLOTS

# %%
# LINE PLOT
plt.subplot(2,2,1)   # (2,2,1) shows we can plot 4 plots, it has 2 rows and 2 columns, Line plot will be plotted at 1st index
plt.plot(x,y1)

# SCATTER PLOT
plt.subplot(2,2,2)
plt.scatter(x,y2)

# Bar PLOT
plt.subplot(2,2,3)
plt.barh(x1,y3)

# PIE CHART
plt.subplot(2,2,4)
plt.pie(y3)


plt.show()

# %% [markdown]
# ## 2. Customize the subplots with titles, axis labels, and legends.

# %%
## 🔹 Extracting little chunks of Data from df to plot 4 plots separately

# %%
df1=df['Temperature_C']
df2=df['Humidity_pct']
df3=df['Precipitation_mm']
df4=df['Wind_Speed_kmh']
df5=df['Location']

x=df1[0:5]
x1=df5[0:5]
y1=df2[0:5]
y2=df3[0:5]
y3=df4[0:5]
y4=df1[0:5]

# %%
# 4 SUBLOTS

plt.suptitle("Multiple Plots with Titles and Labels ",fontsize=16)

# LINE PLOT
plt.subplot(2,2,1)
plt.plot(x,y1)
plt.xlabel("Temperature (C)")
plt.ylabel("Humidity (pct)")
plt.title("Line Plot")


# SCATTER PLOT
plt.subplot(2,2,2)
color=['red','blue','green','brown','orange']
size = [180, 150, 250, 125, 800]
plt.scatter(x, y2, marker='.', c=color, s=size)
plt.xlabel("Temperature (C)")
plt.title("Scatter plot")
plt.ylabel("Precipitation (mm)")


# HORIZONTAL BAR CHART
plt.subplot(2,2,3)
plt.barh(x1,y3)
plt.xlabel("Location")
plt.ylabel("Wind_Speed (kmh)")
plt.title("Bar Plot")


# PIE CHART
plt.subplot(2,2,4)
plt.pie(y3,labels=x1,autopct='%2.1f%%')
plt.title("Pie Chart")
plt.subplots_adjust(left=0.1, right=0.9, top=0.8 , bottom=0.1, wspace=0.5, hspace=0.9)


plt.show()

# %% [markdown]
# ## 🟡 HISTOGRAMS

# %% [markdown]
# ### 1. Create a histogram for a given numerical data set. Customize the number of bins.

# %%
Marks = [12, 15, 22, 35, 37, 45, 50, 55, 65, 68, 70, 75, 80, 85, 90, 95, 100, 42, 58, 78]

plt.hist(Marks,5, histtype='bar', rwidth=0.8)
plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Histogram for single numerical data set \n with gap in bars",fontsize=14,pad=25)

plt.show()

# %% [markdown]
# ## 🔹 Histogram with Different Edge Color

# %%
Marks = [12, 15, 22, 35, 37, 45, 50, 55, 65, 68, 70, 75, 80, 85, 90, 95, 100, 42, 58, 78]

plt.hist(Marks,3, histtype='bar', ec='r')
plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Histogram with edge Color: Red",fontsize=14,pad=20)
plt.show()

# %% [markdown]
# ## 🔹 Histogram with colored bars

# %%
import matplotlib.pyplot as plt

Marks = [12, 15, 22, 35, 37, 45, 50, 55, 65, 68, 70, 75, 80, 85, 90, 95, 100, 42, 58, 78]

plt.hist(Marks, bins=[1,11,21,31,41,51,61,71,81,91,101] , histtype='bar', ec= 'g', fc= 'y')
plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Histogram with colored bars",fontsize=14,pad=20)
plt.show()

# %% [markdown]
# ## 2. Plot multiple histograms on the same figure to compare different data sets

# %% [markdown]
# #### USING TWO DATA SETS

# %%
Marks_in_Maths=[12, 15, 22, 35, 37, 45, 50, 55, 65, 68, 70, 75, 80, 85, 90, 95, 100, 42, 58, 78]
Marks_in_Stats=[25, 30, 32, 33, 33, 40, 43, 45, 52, 60, 65, 67, 68, 75, 85, 99, 63, 59, 92, 93]
plt.figure()

plt.hist(Marks_in_Maths,5,histtype='bar',ec= 'g', fc= 'y',label='MATHS')
plt.hist(Marks_in_Stats, 5, histtype='bar',rwidth=0.5,ec= 'b', fc= 'r',label='STATS')


plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Histogram for comparison of \n Maths and Stats marks",fontsize=14,pad=30)



plt.legend()
plt.show()

# %% [markdown]
# #### USING THREE DATA SETS

# %%
Marks_in_Maths=[90,88,95,93,91,92,45,67,55,43]
Marks_in_Stats=[35,49,88,85,82,84,75,61,85,52]
Marks_in_Linear=[66,75,69,78,90,66,49,58,76,69]
plt.figure()

plt.hist(Marks_in_Maths,5,histtype='bar',rwidth=0.5,ec= 'g', fc= 'y',label='MATHS')
plt.hist(Marks_in_Stats, 5, histtype='bar',rwidth=0.5,ec= 'b', fc= 'r',label='STATS')
plt.hist(Marks_in_Linear,5,histtype='bar',rwidth=0.5,ec= 'g', fc= 'b',label='LINEAR ALGEBRA')

plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Histogram for comparison of \n Maths, Stats and Linear Algebrs marks",fontsize=14,pad=25)



plt.legend()
plt.show()

# %% [markdown]
# ## 3. Normalize the histograms and add appropriate labels and titles.

# %%
Marks_in_Maths=[90,88,95,93,91,92,45,67,55,43]
Marks_in_Stats=[35,49,88,85,82,84,75,61,85,52]
plt.figure()

plt.hist(Marks_in_Maths,5,histtype='bar',density=True, alpha=0.8,rwidth=0.5,ec= 'g', fc= 'y',label='MATHS')
plt.hist(Marks_in_Stats, 5, histtype='bar',density=True, alpha=0.5,rwidth=0.5,ec= 'b', fc= 'r',label='STATS')

plt.xlabel("Marks Range")
plt.ylabel("No of Students")
plt.title("Comparison of Maths and Stats Marks",fontsize=16,pad=30)



plt.legend()
plt.show()

# %% [markdown]
# # 🟡 Box Plots

# %% [markdown]
# ### 1. Create a box plot for a given numerical data set

# %%
df1=df['Temperature_C']


plt.boxplot(df1)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot")

plt.show()

# %% [markdown]
# ### 🔹 Horizontal Box Plot

# %%
df1=df['Temperature_C']


plt.boxplot(df1,vert=False)

plt.xlabel("Temperature in Celsius")
plt.title("Horizontal Box Plot" )

plt.show()

# %% [markdown]
# ### 🔹 Horizontal Box with varying width

# %%
# changing width - default width is 0.2

df1=df['Temperature_C']


plt.boxplot(df1,widths=0.5)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot of the Data Set")

plt.show()

# %% [markdown]
# ### 🔹 Horizontal Box with filled color

# %%
# FILLING COLOR

df1=df['Temperature_C']


plt.boxplot(df1,patch_artist=True)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot of the Data Set")

# Show the plot
plt.show()

# %% [markdown]
# ### 🔹 Horizontal Box with visible mean

# %%
# Showing the mean of data
df1=df['Temperature_C']


plt.boxplot(df1,showmeans=True)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot showing mean in green triangle")

plt.show()

# %% [markdown]
# ### 🔹 Horizontal Box With Visible Outlier

# %%
plt.boxplot(df1)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot with outlier")

plt.show()

# %% [markdown]
# ### 🔹 Box Plot Showing whisker meeting the Outlier

# %%
df1=df['Temperature_C']


plt.boxplot(df1,whis=4)

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot of the Data Set")

# Show the plot
plt.show()

# %% [markdown]
# ###  🔹 Box Plot With Varying Outlier (Color and Symbol)

# %%
# changing color of outlier and changing its shape
df1=df['Temperature_C']


plt.boxplot(df1,sym='g*')

plt.ylabel("Temperature in Celsius")
plt.title("Box Plot with green color outlier and * symbol")

plt.show()

# %% [markdown]
# ###  🔹 Box Plot With Varying Caps Color

# %%
 # ADDING COLOURS

df2=df['Humidity_pct']
plt.boxplot(df2,capprops=dict(color='g'))

plt.ylabel("Humidity (pct)")
plt.title("Box Plot Showing Green Colored Caps",fontsize=14,pad=20)

plt.show()

# %% [markdown]
# ###  🔹 Box Plot With Varying Whiskers Color

# %%
 # ADDING COLOURS
df2=df['Humidity_pct']


plt.boxplot(df2,whiskerprops=dict(color='b'))

plt.ylabel("Humidity (pct)")
plt.title("Box Plot Showing blue Whiskers",fontsize=14,pad=20)

plt.show()

# %% [markdown]
# ###  2.Generate multiple box plots in a single figure to compare different data sets.

# %%
# Generate multiple box plots in a single figure to compare different data sets.

df1=df['Temperature_C']
df2=df['Humidity_pct']
df3=df['Precipitation_mm']
df4=df['Wind_Speed_kmh']

plt.boxplot([df1, df2,df3,df4])
plt.show()

# %% [markdown]
# ## 3.Customize the box plots with titles, labels, and change the colors.

# %%
df1=df['Temperature_C']
df2=df['Humidity_pct']
df3=df['Precipitation_mm']
df4=df['Wind_Speed_kmh']


plt.boxplot([df1, df2,df3,df4], labels=['Temperature ', 'Humidity', 'Precipitation', 'Wind Speed'])

plt.title("Multiple Box Plots",fontsize=14,pad=20)
plt.show()

# %%
df1=df['Temperature_C']
df2=df['Humidity_pct']
df3=df['Precipitation_mm']
df4=df['Wind_Speed_kmh']

whiskerprops = dict(color="blue", linewidth=1.5)
capprops = dict(color="red", linewidth=1.5)

plt.boxplot([df1, df2,df3,df4], labels=['Temperature ', 'Humidity', 'Precipitation', 'Wind Speed'],whiskerprops=whiskerprops,
            capprops=capprops)

plt.title("Multiple Box Plots With Varying Color Whiskers and Caps",fontsize=14,pad=20)
plt.show()
