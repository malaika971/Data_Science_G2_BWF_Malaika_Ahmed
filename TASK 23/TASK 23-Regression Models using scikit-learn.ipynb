# %% [markdown]
# > > > ***Submitted by: Malaika Ahmed***
#
# # 🔴 **Task 23: Regression Models using scikit-learn**
# Explore different regression models and apply them using the sklearn library.
#
#
# ![skit.PNG](attachment:f04b707a-2abb-40e0-a2c7-56573bca7683.PNG)

# %% [markdown]
#  # <span style='color:Red'>  **Overview of scikit-learn** </span>
#
# - Scikit-learn is an open-source Python package. It is a library that provides a set of selected tools for ML and statistical modeling. It includes regression, classification, dimensionality reduction, and clustering. It is properly documented and easy to install and use in a few simple steps.
# at
# - Sm, scikit-learn also provides algorithm variants that can handle more complex da (aside by linear regression model)ta, such as polynomial regression, ridge regression, and Lasso regression. These variants involve adding additional constraints or penalties to the model to prevent overfitting and improve its generalization performance.

# %% [markdown]
# ***
# ***

# %% [markdown]
#  # <span style='color:Blue'>  ***Regression Models*** </span>
#
# Regression models are algorithms employed to predict continuous numerical values based on input features. In scikit-learn, a variety of regression algorithms can be utilized.
#
# ![image.png](attachment:c9d34834-f85b-46fd-989c-1b670febc8d7.png)

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***1. Linear Regression Model*** </span>
#
# Linear regression is one of the simplest and most widely used regression algorithms. It assumes a linear relationship between the input variables and the target variable. The goal is to find the best fit line that minimizes the sum of the squared differences between the predicted and actual values.
#
# ![image.png](attachment:ff66825a-5a3e-4b88-9257-1f8f958a8bf9.png)

# %% [markdown]
# # <span style='color:Green'>  ***Creating a simple Sklearn Linear Regression Model*** </span>

# %% [markdown]
# ### ***1. Importing Libraries***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ***

# %% [markdown]
# ### 2. ***Import the dataset***

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (30, 2)

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***

# %% [markdown]
# ### ***3.Splitting the Data into input (x) and output column (y)***

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['YearsExperience'], df['Salary'], color='blue')

plt.title('Scatter Plot of Years Experience vs. Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### 4: ***Splitting Data into training and testing***

# %%
# test_size shows that 30% will be testing data and 70% will be training data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %% [markdown]
# ### ***Input train data***

# %%
X_train
# Out:
#     YearsExperience
# 20              6.9
# 5               3.0
# 27              9.7
# 12              4.1
# 4               2.3
# 10              4.0
# 16              5.2
# 28             10.4
# 25              9.1
# 17              5.4
# 2               1.6
# 7               3.3
# 26              9.6
# 24              8.8
# 18              6.0
# 11              4.1
# 22              8.0
# 29             10.6
# 13              4.2
# 15              5.0
# 8               3.3

# %% [markdown]
# ### ***Input test data***

# %%
X_test
# Out:
#     YearsExperience
# 1               1.4
# 0               1.2
# 14              4.6
# 9               3.8
# 21              7.2
# 19              6.1
# 23              8.3
# 6               3.1
# 3               2.1

# %% [markdown]
# ### ***Target test data***

# %%
X_test
# Out:
#     YearsExperience
# 1               1.4
# 0               1.2
# 14              4.6
# 9               3.8
# 21              7.2
# 19              6.1
# 23              8.3
# 6               3.1
# 3               2.1

# %% [markdown]
# ### ***Output train data***

# %%
y_train
# Out:
# 20     91739.0
# 5      56643.0
# 27    112636.0
# 12     56958.0
# 4      39892.0
# 10     63219.0
# 16     66030.0
# 28    122392.0
# 25    105583.0
# 17     83089.0
# 2      37732.0
# 7      54446.0
# 26    116970.0
# 24    109432.0
# 18     81364.0
# 11     55795.0
# 22    101303.0
# 29    121873.0
# 13     57082.0
# 15     67939.0
# 8      64446.0
# Name: Salary, dtype: float64

# %%
plt.scatter(X_train,y_train,color='r',alpha=0.7,label='Training Data')
plt.scatter(X_test,y_test,color='g',alpha=0.7,label='Testing Data')
plt.title("Train Test Split")
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### 5. ***Modeling and fitting the data***

# %%
# defining an object for linearRegression
lr=linear_model.LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Scatter plot and regression line
plt.figure(figsize=(10, 6))

plt.scatter(X, y, color='blue', label="Data points")
y_train_predl = lr.predict(x_train)
plt.plot(X_train, y_train_predl, color='red', label="Regression Line")

plt.title('Scatter Plot of Years Experience vs. Salary \n  Using Simple Linear Regression Model',pad=25,fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### ***6. Predictions***

# %%
# The y_test_predl is a numpy array that contains all the predicted values for the input values in the x_test .

y_test_predl = lr.predict(X_test)

df1=pd.DataFrame({'Actual':y_test,'Predicted':np.round( y_test_predl)})
df1.head()
# Out:
#      Actual  Predicted
# 1   46206.0    36145.0
# 0   39344.0    34238.0
# 14  61112.0    66650.0
# 9   57190.0    59023.0
# 21  98274.0    91435.0

# %% [markdown]
# ## ***Results***:
# Overall, the model captures the trend, but there may be room for improvement to reduce prediction errors. Specifically, the model shows a pattern of both overestimating and underestimating certain values. For example, it overestimated the value for the 14th data point (predicted 66650 vs. actual 61112) and underestimated the values for the 1st and 21st data points (predicted 36145 vs. actual 46206 and predicted 91435 vs. actual 98274, respectively). These discrepancies suggest that while the model is generally aligned with the actual data, it might benefit from further refinement, such as incorporating additional features, adjusting model parameters, or exploring more complex models to improve accuracy.

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***2. Polynomial Regression*** </span>
# - Polynomial regression is a form of regression analysis in which the relationship between the independent variable x and the dependent variable y is modelled as an nth degree polynomial in x.It is an extension of linear regression, which only models linear relationships between variables.
#
# - In Polynomial Regression, the relationship between x and y is represented by a polynomial equation, which can capture more complex relationships, including curvature and other non-linear patterns. The degree of the polynomial equation determines the level of complexity in the relationship. The simplest form of Polynomial Regression is a second-degree polynomial, or a quadratic equation, which models the relationship as a parabolic curve.
#
# - Polynomial regression is a useful tool for modeling complex relationships between variables. It can provide more accurate predictions than linear regression for certain types of data.
# -
# One of the main advantages of polynomial regression is that it can fit non-linear relationships between variables, which can provide a more accurate representation of the underlying relationship in the data. However, a high degree polynomial can also lead to overfitting, where the model fits the noise in the data instead of the underlying relationship. This can result in poor predictions for new data. To mitigate this issue, techniques such as cross-validation, regularization, and model selection can be used to select an appropriate degree for the polynomial equation.
#
# ### ***Equation of Polynomial Regression***
# ![image.png](attachment:315541de-95b6-4cf0-9dc1-5a412cac6175.png)
#
# where y is the dependent variable, x is the independent variable and β0, β1, β2, β3, …, βn are the coefficients of the polynomial equation, n is the degree of the polynomial equation
#
# The coefficients β0, β1, β2, β3, …, βn are estimated from the data using regression analysis methods such as least squares or maximum likelihood. The goal is to find the values of these coefficients that provide the best fit to the observed data. The resulting polynomial equation can then be used to make predictions for new values of x.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Polynomial Regression Model*** </span>

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
# Train linear regression model on whole dataset
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
# Train polynomial regression model on the whole dataset
pr = PolynomialFeatures(degree = 4)
X_poly = pr.fit_transform(X)
lr_2 = LinearRegression()
lr_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Predict results
y_pred_lr = lr.predict(X)           # Linear Regression
y_pred_poly = lr_2.predict(X_poly)  # Polynomial Regression

# %% [markdown]
# ## ***Visualize data with linear regression***

# %%
# Visualize data with linear regression

lr = LinearRegression()
lr.fit(x_train, y_train)

# Scatter plot and regression line
plt.figure(figsize=(10, 6))

plt.scatter(x, y, color='blue', label="Data points")
y_train_pred = lr.predict(x_train)
plt.plot(x_train, y_train_pred, color='red', label="Regression Line")

plt.title('Linear Regression Plot of data',pad=25,fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## ***Visualize data with Polynomial Regression***

# %%
plt.figure(figsize=(10, 6))

plt.scatter(X, y, color='blue',  label="Data points")
y_poly_pred = lr_2.predict(X_poly)
plt.plot(X, y_poly_pred, color='red', label="Polynomial Regression Line")

plt.title('Polynomial Regression Plot of Data', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## ***Insights***
#
# The linear regression plot shows a straight line that may not follow the data points closely, especially if the relationship between variables is non-linear While the polynomial regression plot shows a curve that adjusts to the variations in the data, indicating a better fit for capturing the underlying trends and patterns.In summary, linear regression is simpler and less prone to overfitting, polynomial regression can provide a more accurate fit for non-linear relationships in the data.

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***3. Ridge Regression/L2 Normalization*** </span>
#  - Ridge regression is a regularization technique that adds a penalty term to the linear regression cost function to prevent the model from becoming too complex and overfitting the data.When multicollinearity is present, the estimated regression coefficients can become unstable, and the analysis overly sensitive to small variations in the data. This is where Ridge Regression comes in.
#  - Unlike ordinary linear regression, which seeks to minimize the sum of the squares of the residuals (the difference between the observed and predicted values by the model), Ridge Regression adds a penalty term to the calculation.
#  - Ridge regression is the regularized form of linear regression.
#
#  - This penalty term is proportional to the square of the model coefficients, also known as the L2 norm of the coefficientn:
#
# bles.

# %% [markdown]
#  Mathematically, this translates to minimizing the following cost function:
#
# ![image.png](attachment:3b8515db-89ce-4c57-8576-ad4cf02ada5b.png)bles.

# %% [markdown]
# Where:
#
# - J(θ) is the Ridge cost function to be minimized.
# - MSE(θ) is the mean squared error.
# - λ is the regularization hyperparameter.
# - θi are the model coefficients, with i ranging from 1 to n, the number of independent variables.

# %% [markdown]
# ***

# %% [markdown]
# ## ***Key Terms***
#
# ### 1. ***Penality Term: Lambda → λ***
#
# - In Ridge Regression, λ plays a critical role. It allows controlling the relative effects of the two terms. So actually λ is the penalty term. Given λ is represented as an alpha parameter in the Ridge Regression function.
# - By changing the alpha value, we control the penalty term. If λ is zero, this gives us the classical regression equation. Consequently, the higher the Alpha values, the greater the penalty. Therefore, the size of the coefficients is reduced.
#
# ### 2. ***L2 regularization***
# - Regularization is a method of preventing a model from overfitting by adding more information to it and restricting its complexity.
# -
# L2 regularization or L2-norm involves adding a penalty for LARGE variation in the data or if observing the function, for large variation in the w paramete
# - The L2 regularization is applied by the parameter : alpha (ᶐ) being included in the equation.
# -
# Higher the value of alpha, stronger the regularization
#
#
#
# .r
# ![image.png](attachment:cd058796-094a-4066-ad06-332b9665dfd5.png).

# %% [markdown]
# ## ***How does Ridge Regression works***
# - Ridge Regression works by adding a penalty term to the cost function of a linear regression model, called the regularization term. This regularization term prevents the model from overfitting by penalizing the large coefficients.
#
# - The regularization parameter determines how much the model should be penalized. By increasing the regularization parameter, the coefficients are shrunk toward zero..

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Ridge Regression Model*** </span>

# %%
# X is years of experience (input feature) whie y is salary
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
# Fit the Ridge regression model

ridge = Ridge(alpha=1.0)  
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Predicting the training and testing data
y_test_predR = ridge.predict(X_test)

# %%
# Scatter plot and regression line
plt.figure(figsize=(10, 6))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_test_predR, color='red')

plt.title('Ridge Regression: Salary Vs Years of Experience',pad=25,fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#
plt.figure(figsize=(10, 6))

# Plot training data
plt.scatter(y_train, y_train_pred, color='blue', label='Training data')
# Plot testing data
plt.scatter(y_test, y_test_pred, color='green', label='Testing data')

# Plot y=x line for reference
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='y=x line')

plt.title('Ridge Regression: Predicted vs Actual Salary', pad=25, fontsize=16)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***4. Lasso Regression/L1 Normalization*** </span>
# - The “LASSO” stands for Least Absolute Shrinkage and Selection Operator.
# - Lasso Regression is also a type of regularization linear model. It also adds a penalty term to the cost function like ridge but it adds L1 regularization instead of L2 regularization and hence is also known as L1 Regularization or L1 Norm.
# - Lasso regression is a regularization technique. It is used over regression methods for a more accurate prediction. This model uses shrinkage. Shrinkage is where data values are shrunk towards a central point as the mean.
# - The lasso procedure encourages simple, sparse models (i.e. models with fewer parameters).
# - This regression is well-suited for models showing high levels of multicollinearity or when you want to automate certain parts of model selection, like variable selection/parameter elimination.
# -
# It is used when we have a greater number of features because it automatically performs feature selection.

# %% [markdown]
# Mathematically, Lasso Regression is defined by the following equation:
#
#
# > ###  ***Lasso Cost Function = Σ(yᵢ — ŷᵢ)² + λΣ|βⱼ|***
#
# y term.

# %% [markdown]
# Here,
#
# - yᵢ represents the actual target values.
# - ŷᵢ represents the predicted values.
# - βⱼ is the coefficient associated with the jth predictor variable.
# - λ (lambda) is the regularization parameter, which controls the strength of the penalty term.

# %% [markdown]
# ## ***Defining Regularization***
# - Regularization is a technique used in machine learning to penalize complex models to protect them from overfitting.
# - By doing this, regularization helps to prevent models from over-interpreting the noise and randomness found in data sets.
# - In regularization, what we do is normally keep the same number of features but reduce the magnitude of the coefficients. We can reduce the magnitude of the coefficients by using different types of regression techniques that use regularization to overcome this problem.

# %% [markdown]
# ## ***How Lasso Regression Works***
# Lasso Regression works by shrinking the coefficient values associated with less relevant predictor variables to zero. This leads to variable selection, as only the most informative features are retained in the model. The magnitude of the penalty term, controlled by λ, determines the degree of shrinkage. A larger λ value will lead to more coefficients being set to zero, resulting in a simpler and more interpretable model.

# %% [markdown]
# ## ***Difference b/w Ridge and Lasso Regression***
#
# The main difference between Ridge and Lasso regression is the way they shrink the coefficients. Ridge regression can reduce all the coefficients by a small amount but Lasso can reduce some features more than others and hence can completely eliminate those features.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Lasso Regression Model*** </span>

# %%
# Fit the Lasso regression model
lasso = Lasso(alpha=1.0)  # Adjust alpha as needed
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
# Predict the  testing data
y_test_predL = lasso.predict(X_test)

# %%
# Scatter plot and regression line
plt.figure(figsize=(10, 6))

plt.scatter(X_test, y_test, color='blue', label='Actual data')
plt.plot(X_test, y_test_predL, color='red', label='Lasso Regression Line')

plt.title('Lasso Regression: Salary Vs Years of Experience', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Predicted vs Actual Salary plot
plt.figure(figsize=(10, 6))

# Plot training data
plt.scatter(y_train, y_train_pred, color='blue', label='Training data')
# Plot testing data
plt.scatter(y_test, y_test_pred, color='green', label='Testing data')

# Plot y=x line for reference
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='y=x line')

plt.title('Lasso Regression: Predicted vs Actual Salary', pad=25, fontsize=16)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***5. Elastic Net Regression*** </span>
# The main purpose of ElasticNet Regression is to find the coefficients that minimize the sum of error squares by applying a penalty to these coefficients. ElasticNet combines L1 and L2 (Lasso and Ridge) approaches. As a result, it performs a more efficient smoothing process.The elastic net method improves on lasso’s limitations, i.e., where lasso takes a few samples for high dimensional data, the elastic net procedure provides the inclusion of “n” number of variables until saturation. In a case where the variables are highly correlated groups, lasso tends to choose one variable from such groups and ignore the rest entirely.
#
#
# > ### ***Elastic Net first emerged as a result of critique on Lasso, whose variable selection can be too dependent on data and thus unstable. The solution is to combine the penalties of Ridge regression and Lasso to get the best of both worlds.***
#
#
#
#
# ![image.png](attachment:c4302bee-bc0f-4ed6-b986-db173ea7a2d6.png)

# %% [markdown]
# ### ***Features of ElasticNet Regression***
#
#
# - It combines the L1 and L2 approaches.
# - It performs a more efficient regularization process.
# - It has two parameters to be set, λ and α.
#
#
#
# Elastic Net aims at minimizing the following loss function:
#
#
#
# ![image.png](attachment:8594ecf7-173d-4c85-b9f9-a79d9797222f.png)

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Elastic Net Regression Model*** </span>

# %%
# Elastic Net Regression
elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)

# %%
# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
elastic_net.fit(X_train_scaled, y_train)
# Out:
# ElasticNet()

# %%
y_test_pred_en = elastic_net.predict(X_test_scaled)

# %%
# Visualize the results
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Data')
plt.plot(X_test, y_test_pred_en, color='red', label='Elastic Net Regression')
plt.title('Elastic Net Regression: Salary vs Years of Experience', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred_en, color='red')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='blue', linestyle='--', label='y=x line')
plt.title('Predicted vs Actual Salary', pad=25, fontsize=16)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***6. Support Vector Regression (SVR)*** </span>
#
# - Support Vector Regression (SVR) is a regression technique that extends the concepts of Support Vector Machines (SVM) to predict continuous outcomes. The primary objective of SVR is to find a function that can predict the target variable with minimal error.
# -
# Unlike standard regression models, which minimize the sum of squared errors, SVR aims to fit the error within a certain threshold, known as the epsilon-insensitive tub
# - The main Objective of SVR ks to find a function that predicts a continuous target variable while maximizing the margin between the predicted values and the actual data points.
# - This makes it highly suitable for applications where the goal is to forecast a numerical outcome based on a set of input features. For instance, SVR can be used in predicting stock prices, estimating housing costs, or even in more complex tasks like forecasting weather conditions.
#   .

# %% [markdown]
# ## ***Key Terms***
# ### ***Epsilon-Insensitive Tube***
# The epsilon-insensitive tube is a crucial concept in SVR. It defines a margin of tolerance (epsilon) within which the predicted values are considered acceptable and do not incur any loss.
#
# This means that if the difference between the predicted value and the actual value is less than epsilon, the error is ignored. This helps SVR to be robust against small variations in the data and focus on significant deviations.
#
# ### ***Support Vectors***
# Support Vectors are those points in the space that are closer to the hyperplane and also decide the orientation of the hyperplane. The lines or planes drawn is called Support Vector Lines or Support Vector Planes.
#
#
#
# ![image.png](attachment:5d994bd6-7953-4187-a6da-4f386ba567af.png)
#
#
#
# ### ***Hyper Plane***
#  A hyperplane is a plane which is used to divide categories based on their values. A hyperplane is always 1 dimension less than the actual plane used for plotting the outcomes or for analyses. For eg, in Linear Regression with 1 feature and 1 outcome we can make a 2-D plane to depict the relationship and the regression line fitted to that is a 1-D plane. Hence, this plane is called as Hyperplane. Similarly, for a 3-D relationship, we get a 2-D hyperplane.
#
#  ![image.png](attachment:e1c9d4e7-ac4f-4c98-970e-f990e07180c3.png)
#
#
# ### ***Margin Width***
#
# The perpendicular distance between the 2 support vector lines or planes is called Margin Width.
#
# ![image.png](attachment:1f7caf14-22df-4958-a591-799d792b7bf1.png)
#
# ### ***Kernel Trick***
#
#  SVR can use various kernel functions (e.g., linear, polynomial, radial basis function) to transform the feature space, making it possible to model non-linear relationships between input features and the target variable.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Support Vector Regression Model*** </span>

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
svr = SVR(kernel='rbf', C=1.0, epsilon=0.2) 
svr.fit(X_train, y_train)

# Predict the testing data
y_pred_svr = svr.predict(X_test)

# %%
# Scale the data
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# %%
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).ravel()

# Fit the SVR model with RBF kernel
svr = SVR(kernel='rbf', C=1.0, epsilon=0.2)
svr.fit(X_train_scaled, y_train_scaled)

# Predict the testing data
y_pred_svr_scaled = svr.predict(X_test_scaled)

# Inverse transform the predictions
y_pred_svr = scaler_y.inverse_transform(y_pred_svr_scaled.reshape(-1, 1)).ravel()

# %%
plt.figure(figsize=(10, 6))

# Scatter plot of the actual data
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Testing data')

# Regression line
plt.plot(X_test, y_pred_svr, color='red', label='SVR Regression Line')

plt.title('SVR: Salary Vs Years of Experience', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***7.Decision Tree Regression*** </span>
#
# Decision tree regression is a machine learning technique that constructs a tree-like model to predict continuous numerical values.Decision tree regression is a powerful algorithm for predicting continuous numerical values. Its clear and interpretable model allows for easy understanding of the underlying rules and patterns. It handles both categorical and numerical features, automatically handles missing values and outliers, and is robust to irrelevant features. However, it can be prone to overfitting and sensitivity to small variations.
#
# ![image.png](attachment:68e58768-d2a4-4b20-a9bd-56bbc6e62643.png)

# %% [markdown]
# ## ***Working of the algorithm***
#
# ### ***1.Building the Tree***
# At the core of decision tree regression lies a tree-like structure. Imagine you have a dataset with various attributes (features) and their corresponding target values. The algorithm begins by creating a root node that represents the entire dataset.
#
# ### ***2.Splitting the Data***
#
# The algorithm analyzes each feature to determine the best way to divide the data into distinct groups based on their target values. It does this by setting specific conditions or thresholds on the feature values. The split is designed to minimize the differences between target values within each group.
#
# ### ***3.Recursive Splitting***
#
# Once the first split is made, the algorithm creates two child nodes, representing subsets of the original data. Each child node embodies a particular range of values based on the split condition. The algorithm then repeats this process for each child node, recursively splitting the data further based on the best features and conditions.
# ![image.png](attachment:493f0b83-294d-4fa8-b44b-4987ad1e07ee.png)
#
# ### ***4. Stopping Criterion***
#
#
# The recursive splitting process continues until a stopping criterion is met. This criterion can be defined by a maximum depth limit, ensuring the tree doesn’t become too complex. Alternatively, it could be based on having a minimum number of data points in a leaf node, preventing overfitting
#
# ![image.png](attachment:105d595a-c3c3-4b59-94a7-d678a83549bc.png)
#
#
# ### ***5. Making Predictions***
#
#
# To make a prediction for a new data point, the decision tree regression algorithm starts at the root node and follows a path down the tree based on the feature values of the data point. At each node, it checks the condition associated with that node and proceeds to the left or right child node accordingly. This traversal continues until a leaf node is reached.
# ### ***6. Final Prediction***
#
# n:
# The leaf node reached during the traversal contains a predicted value associated with it and that predicted value is average of actual values of the sub group. This value becomes the output of the decision tree regression algorithm for the given data po
#
# ![image.png](attachment:c16b6f52-77e2-4df1-8024-641d798ff6fd.png)int..

# %% [markdown]
# ## **Advantages of Decision Tree Regression**
# - ***Nonlinearity***: Decision trees can capture nonlinear relationships between variables without requiring explicit transformations or assumptions. They are capable of handling complex interactions and can model nonlinear patterns effectively.
#
# - ***Robustness to Outliers:*** Decision trees are less affected by outliers compared to other regression models. The splitting criterion used in decision trees is more resilient to extreme values.
#
# - ***Handling Missing Values:*** Decision trees can handle missing values by automatically considering alternative branches based on available data. This reduces the need for imputation or data preprocessing techniques.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Decision Tree Regression Model*** </span>

# %%
decision_tree_reg = DecisionTreeRegressor(random_state=2, max_depth=None)
decision_tree_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=2)

# %%
# Predict the training and testing data
y_train_pred = decision_tree_reg.predict(X_train)
y_test_pred = decision_tree_reg.predict(X_test)

# %%
# Scatter plot and Decision Tree regression line
plt.figure(figsize=(10, 6))

# Scatter plot of the actual data
plt.scatter(X, y, color='blue', alpha=0.5, label='Data points')

# Predict across the entire range for plotting
X_plot = np.arange(min(X['YearsExperience']), max(X['YearsExperience']), 0.01)[:, np.newaxis]
y_plot = decision_tree_reg.predict(X_plot)
plt.plot(X_plot, y_plot, color='red', label='Decision Tree Regression Line')

plt.title('Decision Tree Regression Plot of Data \n Years Of Experience Vs Salary', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\Malaika ahmad\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Red'>  ***8.Random Forest*** </span>
#
#  Random Forest is an ensemble machine learning algorithm that combines multiple decision trees to create a more robust and accurate predictive model. It was introduced as an improvement over single decision trees to reduce overfitting and improve predictive performance.
#
#
# ![image.png](attachment:226a18a7-93c9-4836-a2cc-0f67479eadf4.png)
#
#
#
# oint.

# %% [markdown]
# ### ***Features of a Random Forest Algorithm***
#
# - It’s more accurate than the decision tree algorithm.
# - It provides an effective way of handling missing data.
# - It can produce a reasonable prediction without hyper-parameter tuning.
# - It solves the issue of overfitting in decision trees.
# - In every random forest tree, a subset of features is selected randomly at the node’s splitting point.

# %% [markdown]
# ***

# %% [markdown]
#  # <span style='color:Green'>  ***Creating a Random Forest Regression Model*** </span>

# %%
random_forest_reg = RandomForestRegressor(n_estimators=100, random_state=2)
random_forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=2)

# %%
# Predict the training and testing data
y_train_pred = random_forest_reg.predict(X_train)
y_test_predRF = random_forest_reg.predict(X_test)

# %%
plt.figure(figsize=(10, 6))

# Scatter plot of the actual data
plt.scatter(X, y, color='blue', alpha=0.5, label='Data points')

# Predict across the entire range for plotting
X_plot = np.arange(min(X['YearsExperience']), max(X['YearsExperience']), 0.01)[:, np.newaxis]
y_plot = random_forest_reg.predict(X_plot)
plt.plot(X_plot, y_plot, color='red', label='Random Forest Regression Line')

plt.title('Random Forest Regression Plot of Data \n Years of Experience Vs Salary', pad=25, fontsize=16)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\Malaika ahmad\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ***

# %% [markdown]
# ## ***Comparing Accuray Scores of Simple Regression, Ridge,Lasso,ElasticNet SVR Decision Tree amd Ramdom Forest***

# %%
#  Linear Regression
R2L=r2_score(y_test,y_test_predl)

print("R2 Accuracy Score using Linear Regression is :", R2L)

# Ridge
R2R=r2_score(y_test,y_test_predR)
print("R2 Accuracy Score using Ridge Regression Model is :", R2R)

# Lasso
R2_lasso=r2_score(y_test,y_test_predL)
print("R2 Accuracy Score using Lasso Regression Model is :",R2_lasso)

# Elastirc Net 
R2EN=r2_score(y_test,y_test_pred_en)
print("R2 Accuracy Score using Elastic Net Regression Model is :",R2EN)

R2SVR=r2_score(y_test,y_pred_svr_scaled)
print("R2 Accuracy Score using Support Vector Regression Model is :",R2SVR)

R2DT = r2_score(y_test, y_predDT)
print("R2 Accuracy Score using Decision Tree Regression Model is :",R2DT)

R2RF = r2_score(y_test,y_test_predRF)
print("R2 Accuracy Score using Random Forest Regression Model is :",R2RF)
# Out:
# R2 Accuracy Score using Linear Regression is : 0.9002142249159952
# R2 Accuracy Score using Ridge Regression Model is : 0.9010580827092892
# R2 Accuracy Score using Lasso Regression Model is : 0.9002161979504009
# R2 Accuracy Score using Elastic Net Regression Model is : 0.8109694772520419
# R2 Accuracy Score using Support Vector Regression Model is : -7.200562371667383
# R2 Accuracy Score using Decision Tree Regression Model is : 0.9415886440617879
# R2 Accuracy Score using Random Forest Regression Model is : 0.9444333533507058

# %% [markdown]
# ***
