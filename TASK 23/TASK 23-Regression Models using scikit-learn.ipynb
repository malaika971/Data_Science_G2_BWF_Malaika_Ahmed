# %% [markdown]
# > > > ***Submitted by: Malaika Ahmed***
#
# # 🔴 **Task 23: Regression Models using scikit-learn**
# Explore different regression models and apply them using the sklearn library.
#
#
# ![skit.PNG](attachment:f04b707a-2abb-40e0-a2c7-56573bca7683.PNG)

# %% [markdown]
#  # <span style='color:Red'>  **Overview of scikit-learn** </span>
#
# - Linear Regression is a supervised learning algorithm for predicting continuous values based on input variables. This algorithm establishes a linear relationship between the independent variables (input variables, features, or predictors) and the dependent variable (output variable or target variable).
# - Scikit-learn is an open-source Python package. It is a library that provides a set of selected tools for ML and statistical modeling. It includes regression, classification, dimensionality reduction, and clustering. It is properly documented and easy to install and use in a few simple steps.
#
# - The scikit-learn implements Linear Regression through the LinearRegression class. This class allows us to fit a linear model to a dataset, predict new values, and evaluate the model's performance.
# -
# To use the LinearRegression class, we first need to import it from sklearn.linear_model module. We can then create an instance of the class and call its fit method to train the model on a dataset. Finally, we can use the prediction method to generate predictions on new dat
# - Sm, scikit-learn also provides algorithm variants that can handle more complex data, such as polynomial regression, ridge regression, and Lasso regression. These variants involve adding additional constraints or penalties to the model to prevent overfitting and improve its generalization performance.

# %% [markdown]
#  # <span style='color:Red'>  ***Creating a Sklearn Linear Regression Model*** </span>

# %% [markdown]
# ### ***1. Importing Libraries***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ***

# %% [markdown]
# ### 2. ***Import the dataset***

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***

# %% [markdown]
# ### ***3.Splitting the Data into input (x) and output column (y)***

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
del df['Unnamed: 0']

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['YearsExperience'], df['Salary'], color='blue', alpha=0.5)

plt.title('Scatter Plot of Years Experience vs. Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### 4: ***Splitting Data into training and testing***

# %%
# test_size shows that 30% will be testing data and 70% will be training data

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %% [markdown]
# ### ***Input train data***

# %%
x_train
# Out:
#     YearsExperience
# 0               1.2
# 4               2.3
# 16              5.2
# 5               3.0
# 13              4.2
# 11              4.1
# 22              8.0
# 1               1.4
# 2               1.6
# 25              9.1
# 3               2.1
# 21              7.2
# 26              9.6
# 18              6.0
# 29             10.6
# 20              6.9
# 7               3.3
# 10              4.0
# 14              4.6
# 19              6.1
# 6               3.1

# %% [markdown]
# ### ***Input test data***

# %%
x_test
# Out:
#     YearsExperience
# 27              9.7
# 15              5.0
# 23              8.3
# 17              5.4
# 8               3.3
# 9               3.8
# 28             10.4
# 24              8.8
# 12              4.1

# %% [markdown]
# ### ***Target test data***

# %%
y_test
# Out:
# 27    112636.0
# 15     67939.0
# 23    113813.0
# 17     83089.0
# 8      64446.0
# 9      57190.0
# 28    122392.0
# 24    109432.0
# 12     56958.0
# Name: Salary, dtype: float64

# %% [markdown]
# ### ***Output train data***

# %%
y_train
# Out:
# 0      39344.0
# 4      39892.0
# 16     66030.0
# 5      56643.0
# 13     57082.0
# 11     55795.0
# 22    101303.0
# 1      46206.0
# 2      37732.0
# 25    105583.0
# 3      43526.0
# 21     98274.0
# 26    116970.0
# 18     81364.0
# 29    121873.0
# 20     91739.0
# 7      54446.0
# 10     63219.0
# 14     61112.0
# 19     93941.0
# 6      60151.0
# Name: Salary, dtype: float64

# %%
plt.scatter(x_train,y_train,color='r',alpha=0.7,label='Training Data')
plt.scatter(x_test,y_test,color='g',alpha=0.7,label='Testing Data')
plt.title("Train Test Split")
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### 5. ***Modeling and fitting the data***

# %%
# defining an object for linearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Fit the Linear Regression model
lr = LinearRegression()
lr.fit(x_train, y_train)

# Scatter plot and regression line
plt.figure(figsize=(10, 6))

plt.scatter(x, y, color='blue', alpha=0.5, label="Data points")
y_train_pred = lr.predict(x_train)
plt.plot(x_train, y_train_pred, color='red', label="Regression Line")

plt.title('Scatter Plot of Years Experience vs. Salary \n after fitting the data')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### ***6. Predictions***

# %%
# The y_pred is a numpy array that contains all the predicted values for the input values in the x_test .

y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

df1=pd.DataFrame({'Actual':y_test,'Predicted':np.round( y_test_pred)})
df1.head()
# Out:
#      Actual  Predicted
# 1   46206.0    36145.0
# 0   39344.0    34238.0
# 14  61112.0    66650.0
# 9   57190.0    59023.0
# 21  98274.0    91435.0

# %% [markdown]
# #### **Results: The predicted value is close to the actual value.**

# %% [markdown]
# ***
