# %% [markdown]
# # 🔴 Task 14: Data cleaning and preprocessing with Pandas
# #### Submitted by: Malaika Ahmed

# %% [markdown]
# ## 1.Identify missing values in the DataFrame.

# %% [markdown]
# #### i) IMPORTING CSV FILE

# %%
import pandas as pd
import numpy as np

pd.read_csv("Desktop/TASK#14_BWF_Malaika/movies.csv")
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# #### ii) SETTING THE CSV FILE TO VARIABLE "MOVIES" AND FINDING MISSING VALUES

# %%
movies=pd.read_csv("Desktop/TASK#14_BWF_Malaika/movies.csv")
movies.isnull()
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime  Gross
# 0      False  False  False   False     False  False  False    False   True
# 1      False  False  False   False     False  False  False    False   True
# 2      False  False  False   False     False  False  False    False   True
# 3      False  False  False   False     False  False  False    False   True
# 4      False  False  False    True     False  False   True     True   True
# ...      ...    ...    ...     ...       ...    ...    ...      ...    ...
# 9994   False  False  False    True     False  False   True     True   True
# 9995   False  False  False    True     False  False   True     True   True
# 9996   False  False  False    True     False  False   True     True   True
# 9997   False  False  False    True     False  False   True     True   True
# 9998   False  False  False    True     False  False   True     True   True
#
# [9999 rows x 9 columns]

# %% [markdown]
# #### iii) FINDING THE TOTAL NUMBER OF MISSING VALUES IN EACH COLUMN

# %%
movies.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %% [markdown]
# #### iii) FINDING THE TOTAL SUM OF MISSING VALUES IN ALL COLUMNS

# %%
movies.isnull().sum().sum()
# Out:
# 16861

# %% [markdown]
# ## 2. Drop rows with any missing values.

# %%
df1=movies.dropna()
df1
# Out:
#                                                  MOVIES        YEAR  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                           GENRE  RATING  \
# 77          \nAction, Comedy, Crime                 6.9
# ...

# %% [markdown]
# #### CHECKING IF THERSE ANY ROW LEFT WITH MISSING VALUES

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 3.Drop columns with any missing values.

# %%
df2=movies.dropna(axis=1)
df2
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# ...

# %% [markdown]
# #### CHECKING IF THERSE ANY COLUMN LEFT WITH MISSING VALUES

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 4.Fill missing values with a specific value.

# %%
df3=movies.fillna(value=0)
print(df3)
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %% [markdown]
# ## 5.Fill missing values using forward fill and backward fill methods.

# %% [markdown]
# #### FORWARD FILL

# %%
## FORWARD FILL 
# First extracting rows 2 to 6 of column "RATING" in dataframe "movies" for ease of display

df4=movies['RATING']
df4.iloc[2:7]
# Out:
# 2    8.2
# 3    9.2
# 4    NaN
# 5    7.6
# 6    6.8
# Name: RATING, dtype: float64

# %%
dff=df4.iloc[2:7]
dff.ffill()
# Out:
# 2    8.2
# 3    9.2
# 4    9.2
# 5    7.6
# 6    6.8
# Name: RATING, dtype: float64

# %% [markdown]
# #### BACKWARD FILL

# %%
## BACKWARD FILL 
# First extracting rows 2 to 6 of column "RATING" in dataframe "movies" for ease of display

df4=movies['RATING']
df4.iloc[2:7]
# Out:
# 2    8.2
# 3    9.2
# 4    NaN
# 5    7.6
# 6    6.8
# Name: RATING, dtype: float64

# %%
dff=df4.iloc[2:7]
dff.bfill()
# Out:
# 2    8.2
# 3    9.2
# 4    7.6
# 5    7.6
# 6    6.8
# Name: RATING, dtype: float64

# %% [markdown]
# ## 6. Interpolate missing values.

# %%
# First extracting rows 0 to 8 of column "RATING" in dataframe "movies, so we can easily see the required output

df6=movies['RATING']
df6[0:9]
# Out:
# 0    6.1
# 1    5.0
# 2    8.2
# 3    9.2
# 4    NaN
# 5    7.6
# 6    6.8
# 7    8.6
# 8    7.9
# Name: RATING, dtype: float64

# %%
dfi=df6[0:9]
dfi.interpolate()
# Out:
# 0    6.1
# 1    5.0
# 2    8.2
# 3    9.2
# 4    8.4
# 5    7.6
# 6    6.8
# 7    8.6
# 8    7.9
# Name: RATING, dtype: float64

# %% [markdown]
# ## 7.Convert a column to a different data type.

# %%
# First extracting rows 0 to 3 of column "RATING" in dataframe "movies, so we can easily see the required output
df6=movies['RATING']
df6[0:4]
# Out:
# 0    6.1
# 1    5.0
# 2    8.2
# 3    9.2
# Name: RATING, dtype: float64

# %%
df7=df6[0:4]
df7.astype(int)
# Out:
# 0    6
# 1    5
# 2    8
# 3    9
# Name: RATING, dtype: int32

# %% [markdown]
# ## 8. Apply a function to transform the values of a column.

# %%
# First extracting columns "RATING" and "YEAR" from dataframe "movies", so we can easily see the required output

movies[['RATING','YEAR']]
# Out:
#       RATING         YEAR
# 0        6.1       (2021)
# 1        5.0     (2021– )
# 2        8.2  (2010–2022)
# 3        9.2     (2013– )
# 4        NaN       (2021)
# ...      ...          ...
# 9994     NaN     (2021– )
# 9995     NaN     (2021– )
# 9996     NaN     (2022– )
# 9997     NaN     (2021– )
# 9998     NaN     (2021– )
#
# [9999 rows x 2 columns]

# %%
# Further extracting rows 0 to 3 of columns "RATING" and "YEAR" from dataframe "movies", so we can easily see the required output

a=movies[['RATING','YEAR']]
a.iloc[0:4]
# Out:
#    RATING         YEAR
# 0     6.1       (2021)
# 1     5.0     (2021– )
# 2     8.2  (2010–2022)
# 3     9.2     (2013– )

# %%
# converting float values into integer so it may fit exactly into function
b=a.iloc[0:4]
b['RATING'].astype(int)
# Out:
# 0    6
# 1    5
# 2    8
# 3    9
# Name: RATING, dtype: int32

# %%
c=b['RATING'].astype(int)

# %%
def  add_two(x):
    return x + 2

c.apply(add_two)
# Out:
# 0     8
# 1     7
# 2    10
# 3    11
# Name: RATING, dtype: int64

# %% [markdown]
# ## 9. Normalize a column using Min-Max scaling.

# %%
# Extracting 0 to 3 rows of both columns "RATING" and "RunTime" from dataframe "movies", so we can easily see the required output

a=movies[['RATING','RunTime']]
b=a[0:4]
b
# Out:
#    RATING  RunTime
# 0     6.1    121.0
# 1     5.0     25.0
# 2     8.2     44.0
# 3     9.2     23.0

# %%
b.describe()
# Out:
#          RATING     RunTime
# count  4.000000    4.000000
# mean   7.125000   53.250000
# std    1.917246   46.147409
# min    5.000000   23.000000
# 25%    5.825000   24.500000
# 50%    7.150000   34.500000
# 75%    8.450000   63.250000
# max    9.200000  121.000000

# %%
# Importing library MinMaxScaler

from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()
b =Scaler.fit_transform(b)
print("Normalized columns after min max scaling \n \n",b)
# Out:
# Normalized columns after min max scaling
#
#  [[0.26190476 1.        ]
#  [0.         0.02040816]
#  [0.76190476 0.21428571]
#  [1.         0.        ]]

# %% [markdown]
# #### CHECKING IF COLUMNS ARE CORRECTLY NORMALIZED BY TAKING ITS MEAN AND STANDARD DEVIATION(Normally both should centre around 0.5)

# %%
b.mean()
# Out:
# 0.407312925170068

# %%
b.std()
# Out:
# 0.4135512783971844

# %% [markdown]
# ## 10. Standardize a column (z-score normalization).

# %%
# Importing library StandardScaler

from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
c =Scaler.fit_transform(c)
c
# Out:
# array([[-0.61732708,  1.69524061],
#        [-1.27982443, -0.70687155],
#        [ 0.6474406 , -0.23145352],
#        [ 1.24971092, -0.75691555]])

# %% [markdown]
# #### CHECKING IF COLUMNS ARE CORRECTLY STANDARDIZE BY TAKING ITS MEAN AND STANDARD DEVIATION( MEAN SHOULD BE ZERO AND STANDARD DEVIATION SHOULD BE 1)

# %%
np.mean(c)
# Out:
# 0.0

# %%
np.std(c)
# Out:
# 1.0

# %% [markdown]
# ## 11. Identify duplicate rows in the DataFrame.

# %%
df11=movies.duplicated()
df11
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994     True
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9999, dtype: bool

# %%
# checking the total number of duplicated rows 
df11.sum()
# Out:
# 431

# %% [markdown]
# ## 12. Drop duplicate rows.

# %%
df12=df11.drop_duplicates()

# %%
# cheking if theres still any duplicated row left

df12.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 13. Drop duplicate rows based on specific columns.

# %%
movies.drop_duplicates(subset=['YEAR'])
# Out:
#                                    MOVIES               YEAR  \
# 0                           Blood Red Sky             (2021)
# 1     Masters of the Universe: Revelation           (2021– )
# 2                        The Walking Dead        (2010–2022)
# 3                          Rick and Morty           (2013– )
# 5                             Outer Banks           (2020– )
# ...                                   ...                ...
# 6429                Hans Liberg: Tatatata  (2005 TV Special)
# 6467                            Yoga Time        (2004–2009)
# 6473                             Nohzdyve  (2018 Video Game)
# 6474                  American Experience           (1988– )
# 6643                     American Masters           (1985– )
#
#                                               GENRE  RATING  \
# 0            \nAction, Horror, Thriller                 6.1
# 1        \nAnimation, Action, Adventure                 5.0
# ...

# %%
ddc=movies.drop_duplicates(subset=['YEAR'])

# cheking if theres still any duplicated row left 
ddc.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 14. Convert all string values in a column to lowercase.

# %%
movies['MOVIES'].str.lower()
# Out:
# 0                             blood red sky
# 1       masters of the universe: revelation
# 2                          the walking dead
# 3                            rick and morty
# 4                           army of thieves
#                        ...
# 9994                         the imperfects
# 9995                                 arcane
# 9996                      heart of invictus
# 9997                         the imperfects
# 9998                         the imperfects
# Name: MOVIES, Length: 9999, dtype: object

# %% [markdown]
# ## 15 Remove leading and trailing spaces from string values in a column.

# %%
movies['MOVIES'].str.strip()
# Out:
# 0                             Blood Red Sky
# 1       Masters of the Universe: Revelation
# 2                          The Walking Dead
# 3                            Rick and Morty
# 4                           Army of Thieves
#                        ...
# 9994                         The Imperfects
# 9995                                 Arcane
# 9996                      Heart of Invictus
# 9997                         The Imperfects
# 9998                         The Imperfects
# Name: MOVIES, Length: 9999, dtype: object

# %% [markdown]
# ## 16 Replace a specific substring in a column with another substring.

# %%
movies['MOVIES'].str.replace('Blood ','Dark ')
# Out:
# 0                              Dark Red Sky
# 1       Masters of the Universe: Revelation
# 2                          The Walking Dead
# 3                            Rick and Morty
# 4                           Army of Thieves
#                        ...
# 9994                         The Imperfects
# 9995                                 Arcane
# 9996                      Heart of Invictus
# 9997                         The Imperfects
# 9998                         The Imperfects
# Name: MOVIES, Length: 9999, dtype: object

# %% [markdown]
# ## 17 Extract a substring from each value in a column.

# %%
movies['MOVIES'].str[:5]
# Out:
# 0       Blood
# 1       Maste
# 2       The W
# 3       Rick
# 4       Army
#         ...
# 9994     The
# 9995     Arca
# 9996     Hear
# 9997     The
# 9998     The
# Name: MOVIES, Length: 9999, dtype: object

# %% [markdown]
# ## 18 Convert a column to datetime format.

# %% [markdown]
# ### Importing second data file "weatherdata"-
# #### Using second data set "WeatherData" from Q18 to Q23

# %%
ds2=pd.read_csv('Desktop/TASK#14_BWF_Malaika/weatherdata.csv')

# %%
ds2['Date_Time'] = pd.to_datetime(ds2['Date_Time'])  
ds2
# Out:
#             Location           Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego 2024-01-14 21:12:00      10.683001     41.195754
# 1          San Diego 2024-05-17 15:22:00       8.734140     58.319107
# 2          San Diego 2024-05-11 09:30:00      11.632436     38.820175
# 3       Philadelphia 2024-02-26 17:32:00      -8.628976     54.074474
# 4        San Antonio 2024-04-29 13:23:00      39.808213     72.899908
# ...              ...                 ...            ...           ...
# 999915       Phoenix 2024-04-29 20:49:00      13.335441     39.649131
# 999916      New York 2024-01-30 15:04:00       1.837912     66.505813
# 999917   Los Angeles 2024-03-27 12:25:00      34.641340     78.108101
# 999918  Philadelphia 2024-04-06 23:13:00      25.456678     37.764932
# 999919        Dallas 2024-04-20 19:37:00      12.781843     71.636138
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# 1               9.111623       27.715161
# ...

# %%
# Checking whether it has actually converted into date_time
type(ds2.Date_Time[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## 19. Extract year, month, and day from a datetime column.

# %%
ds2['Year'] = ds2['Date_Time'].dt.year
ds2['Month'] = ds2['Date_Time'].dt.month
ds2['Day'] = ds2['Date_Time'].dt.day

ds2
# Out:
#             Location           Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego 2024-01-14 21:12:00      10.683001     41.195754
# 1          San Diego 2024-05-17 15:22:00       8.734140     58.319107
# 2          San Diego 2024-05-11 09:30:00      11.632436     38.820175
# 3       Philadelphia 2024-02-26 17:32:00      -8.628976     54.074474
# 4        San Antonio 2024-04-29 13:23:00      39.808213     72.899908
# ...              ...                 ...            ...           ...
# 999915       Phoenix 2024-04-29 20:49:00      13.335441     39.649131
# 999916      New York 2024-01-30 15:04:00       1.837912     66.505813
# 999917   Los Angeles 2024-03-27 12:25:00      34.641340     78.108101
# 999918  Philadelphia 2024-04-06 23:13:00      25.456678     37.764932
# 999919        Dallas 2024-04-20 19:37:00      12.781843     71.636138
#
#         Precipitation_mm  Wind_Speed_kmh  Year  Month  Day
# 0               4.020119        8.233540  2024      1   14
# ...

# %% [markdown]
# ## 20.Filter rows based on a date range.

# %%
f_ds2 = ds2[(ds2['Date_Time'] >= '2024-01-14') & (ds2['Date_Time'] <= '2024-01-15')]

f_ds2
# Out:
#             Location           Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego 2024-01-14 21:12:00      10.683001     41.195754
# 80      Philadelphia 2024-01-14 23:48:00       5.415682     79.806351
# 114         New York 2024-01-14 09:27:00      24.360243     45.714208
# 142           Dallas 2024-01-14 02:38:00       9.887183     56.355608
# 437      San Antonio 2024-01-14 00:50:00      -3.675929     71.359750
# ...              ...                 ...            ...           ...
# 999249     San Diego 2024-01-14 07:17:00      23.687133     83.464677
# 999398  Philadelphia 2024-01-14 17:58:00      -4.766156     47.645385
# 999545       Chicago 2024-01-14 05:42:00      -9.437241     72.786064
# 999595  Philadelphia 2024-01-14 11:02:00       3.286987     71.650028
# 999637       Phoenix 2024-01-14 17:06:00       2.403466     47.810851
#
#         Precipitation_mm  Wind_Speed_kmh  Year  Month  Day
# 0               4.020119        8.233540  2024      1   14
# ...

# %% [markdown]
# ## 21. Convert a categorical column to numerical using one-hot encoding.

# %%
# Displaying the total numerical columns in data set "weather data"

ds2_num=ds2.select_dtypes(np.number)
ds2_num
# Out:
#         Temperature_C  Humidity_pct  Precipitation_mm  Wind_Speed_kmh
# 0           10.683001     41.195754          4.020119        8.233540
# 1            8.734140     58.319107          9.111623       27.715161
# 2           11.632436     38.820175          4.607511       28.732951
# 3           -8.628976     54.074474          3.183720       26.367303
# 4           39.808213     72.899908          9.598282       29.898622
# ...               ...           ...               ...             ...
# 999915      13.335441     39.649131          8.949140       14.625911
# 999916       1.837912     66.505813          4.934130        4.797305
# 999917      34.641340     78.108101          8.131816       19.607961
# 999918      25.456678     37.764932          6.724407        0.775982
# 999919      12.781843     71.636138          2.745614       13.026679
#
# [999920 rows x 4 columns]

# %%
# Displaying the total Categorical columns in data set "weather data"
ds2_cat=ds2.select_dtypes(object)

ds2_cat
# Out:
#             Location
# 0          San Diego
# 1          San Diego
# 2          San Diego
# 3       Philadelphia
# 4        San Antonio
# ...              ...
# 999915       Phoenix
# 999916      New York
# 999917   Los Angeles
# 999918  Philadelphia
# 999919        Dallas
#
# [999920 rows x 1 columns]

# %%
ds2_one_hot = pd.get_dummies(ds2_cat, columns=['Location'])
ds2_one_hot
# Out:
#         Location_Chicago  Location_Dallas  Location_Houston  \
# 0                  False            False             False
# 1                  False            False             False
# 2                  False            False             False
# 3                  False            False             False
# 4                  False            False             False
# ...                  ...              ...               ...
# 999915             False            False             False
# 999916             False            False             False
# 999917             False            False             False
# 999918             False            False             False
# 999919             False             True             False
#
#         Location_Los Angeles  Location_New York  Location_Philadelphia  \
# 0                      False              False                  False
# 1                      False              False                  False
# ...

# %% [markdown]
# ## 22.Convert a categorical column to numerical using label encoding.

# %%
# Importing library LabelEncoder

from sklearn.preprocessing import LabelEncoder

ds2['Location_Encoded'] = LabelEncoder().fit_transform(ds2['Location'])
ds2
# Out:
#             Location           Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego 2024-01-14 21:12:00      10.683001     41.195754
# 1          San Diego 2024-05-17 15:22:00       8.734140     58.319107
# 2          San Diego 2024-05-11 09:30:00      11.632436     38.820175
# 3       Philadelphia 2024-02-26 17:32:00      -8.628976     54.074474
# 4        San Antonio 2024-04-29 13:23:00      39.808213     72.899908
# ...              ...                 ...            ...           ...
# 999915       Phoenix 2024-04-29 20:49:00      13.335441     39.649131
# 999916      New York 2024-01-30 15:04:00       1.837912     66.505813
# 999917   Los Angeles 2024-03-27 12:25:00      34.641340     78.108101
# 999918  Philadelphia 2024-04-06 23:13:00      25.456678     37.764932
# 999919        Dallas 2024-04-20 19:37:00      12.781843     71.636138
#
#         Precipitation_mm  Wind_Speed_kmh  Year  Month  Day  Location_Encoded
# ...

# %% [markdown]
# ## 23. Group values in a categorical column and create a new column with grouped categories.

# %%
ds2[['Location','Date_Time']]
# Out:
#             Location           Date_Time
# 0          San Diego 2024-01-14 21:12:00
# 1          San Diego 2024-05-17 15:22:00
# 2          San Diego 2024-05-11 09:30:00
# 3       Philadelphia 2024-02-26 17:32:00
# 4        San Antonio 2024-04-29 13:23:00
# ...              ...                 ...
# 999915       Phoenix 2024-04-29 20:49:00
# 999916      New York 2024-01-30 15:04:00
# 999917   Los Angeles 2024-03-27 12:25:00
# 999918  Philadelphia 2024-04-06 23:13:00
# 999919        Dallas 2024-04-20 19:37:00
#
# [999920 rows x 2 columns]

# %%
a=ds2[['Location','Date_Time']]

# %%
a[0:6]
# Out:
#        Location           Date_Time
# 0     San Diego 2024-01-14 21:12:00
# 1     San Diego 2024-05-17 15:22:00
# 2     San Diego 2024-05-11 09:30:00
# 3  Philadelphia 2024-02-26 17:32:00
# 4   San Antonio 2024-04-29 13:23:00
# 5     San Diego 2024-01-21 08:54:00

# %%
b=a[0:6]

# %%
b.groupby('Location')

# %%
bg=b.groupby('Location')

# %%
for Location, Location_b in bg:
  print(Location)
  print(Location_b)
  print("\n")
# Out:
# Philadelphia
#        Location           Date_Time
# 3  Philadelphia 2024-02-26 17:32:00
#
#
# San Antonio
#       Location           Date_Time
# 4  San Antonio 2024-04-29 13:23:00
#
#
# San Diego
#     Location           Date_Time
# 0  San Diego 2024-01-14 21:12:00
# 1  San Diego 2024-05-17 15:22:00
# 2  San Diego 2024-05-11 09:30:00
# 5  San Diego 2024-01-21 08:54:00

# %% [markdown]
# ## 24 Merge two DataFrames based on a common column.

# %% [markdown]
# #### Using first data set "Movies" from Q24 to Q29

# %%
# Extracting columns 'MOVIES','YEAR' and'GENRE' from data set "movies"

movies[['MOVIES','YEAR','GENRE']]
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE
# 0         \nAction, Horror, Thriller
# 1     \nAnimation, Action, Adventure
# 2          \nDrama, Horror, Thriller
# 3     \nAnimation, Adventure, Comedy
# 4            \nAction, Crime, Horror
# ...                                          ...
# ...

# %%
df1=movies[['MOVIES','YEAR','GENRE']]

# %% [markdown]
# df1[0:3]

# %%
# Creating 1st mini dataframe df1 (rows 0 to 2)

df1[0:3]
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE
# 0      \nAction, Horror, Thriller
# 1  \nAnimation, Action, Adventure
# 2       \nDrama, Horror, Thriller

# %%
df1a=df1[0:3]

# %%
movies[['VOTES','YEAR','RATING']]
# Out:
#         VOTES         YEAR  RATING
# 0      21,062       (2021)     6.1
# 1      17,870     (2021– )     5.0
# 2     885,805  (2010–2022)     8.2
# 3     414,849     (2013– )     9.2
# 4         NaN       (2021)     NaN
# ...       ...          ...     ...
# 9994      NaN     (2021– )     NaN
# 9995      NaN     (2021– )     NaN
# 9996      NaN     (2022– )     NaN
# 9997      NaN     (2021– )     NaN
# 9998      NaN     (2021– )     NaN
#
# [9999 rows x 3 columns]

# %%
df2=movies[['VOTES','YEAR','RATING']]

# %%
# Creating 2nd mini dataframe df2 (rows 0 to 2)

df2[0:3]
# Out:
#      VOTES         YEAR  RATING
# 0   21,062       (2021)     6.1
# 1   17,870     (2021– )     5.0
# 2  885,805  (2010–2022)     8.2

# %%
df2a=df2[0:3]

# %%
# Merging both data frames on common column "YEAR"

pd.merge(df1a,df2a,on='YEAR')
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE    VOTES  RATING
# 0      \nAction, Horror, Thriller               21,062     6.1
# 1  \nAnimation, Action, Adventure               17,870     5.0
# 2       \nDrama, Horror, Thriller              885,805     8.2

# %%
df3=pd.merge(df1a,df2a,on='YEAR')

# %% [markdown]
# ## 25 Concatenate two DataFrames vertically.

# %%
# Creating 1st mini dataframe df1 (rows 0 to 2)

df1[0:3]
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE
# 0      \nAction, Horror, Thriller
# 1  \nAnimation, Action, Adventure
# 2       \nDrama, Horror, Thriller

# %%
df1a=df1[0:3]

# %%
# Creating 2nd mini dataframe df2 (rows 0 to 2)

df2[0:3]
# Out:
#      VOTES         YEAR  RATING
# 0   21,062       (2021)     6.1
# 1   17,870     (2021– )     5.0
# 2  885,805  (2010–2022)     8.2

# %%
df2a=df2[0:3]

# %%
pd.concat([df1a,df2a],axis=0)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 0                                  NaN       (2021)
# 1                                  NaN     (2021– )
# 2                                  NaN  (2010–2022)
#
#                                         GENRE    VOTES  RATING
# 0      \nAction, Horror, Thriller                  NaN     NaN
# 1  \nAnimation, Action, Adventure                  NaN     NaN
# 2       \nDrama, Horror, Thriller                  NaN     NaN
# 0                                         NaN   21,062     6.1
# 1                                         NaN   17,870     5.0
# 2                                         NaN  885,805     8.2

# %%
# Concatenating both data frames

df4=pd.concat([df1a,df2a],axis=0)

# %%
df4
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 0                                  NaN       (2021)
# 1                                  NaN     (2021– )
# 2                                  NaN  (2010–2022)
#
#                                         GENRE    VOTES  RATING
# 0      \nAction, Horror, Thriller                  NaN     NaN
# 1  \nAnimation, Action, Adventure                  NaN     NaN
# 2       \nDrama, Horror, Thriller                  NaN     NaN
# 0                                         NaN   21,062     6.1
# 1                                         NaN   17,870     5.0
# 2                                         NaN  885,805     8.2

# %% [markdown]
# ## 26 Concatenate two DataFrames horizontally.

# %%
# Creating 1st mini dataframe df1 (rows 0 to 2)
df1[0:3]
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE
# 0      \nAction, Horror, Thriller
# 1  \nAnimation, Action, Adventure
# 2       \nDrama, Horror, Thriller

# %%
df1a=df1[0:3]

# %%
# Creating 2nd mini dataframe df3 (rows 0 to 2)

df2[0:3]
# Out:
#      VOTES         YEAR  RATING
# 0   21,062       (2021)     6.1
# 1   17,870     (2021– )     5.0
# 2  885,805  (2010–2022)     8.2

# %%
df2a=df2[0:3]

# %%
# Concatenating both data frames

pd.concat([df1a,df2a],axis=1)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE    VOTES         YEAR  RATING
# 0      \nAction, Horror, Thriller               21,062       (2021)     6.1
# 1  \nAnimation, Action, Adventure               17,870     (2021– )     5.0
# 2       \nDrama, Horror, Thriller              885,805  (2010–2022)     8.2

# %%
df5=pd.concat([df1a,df2a],axis=1)

# %%
df5
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE    VOTES         YEAR  RATING
# 0      \nAction, Horror, Thriller               21,062       (2021)     6.1
# 1  \nAnimation, Action, Adventure               17,870     (2021– )     5.0
# 2       \nDrama, Horror, Thriller              885,805  (2010–2022)     8.2

# %% [markdown]
# ## 27 Create a new column based on existing columns.

# %%
# Extracting columns "MOVIES" and "GENRE" from mini dataframe df5 of data set "Movies"
df5['MOVIES']  + df5['GENRE']
# Out:
# 0    Blood Red Sky\nAction, Horror, Thriller       ...
# 1    Masters of the Universe: Revelation\nAnimation...
# 2    The Walking Dead\nDrama, Horror, Thriller     ...
# dtype: object

# %%
# Creating new column "MOVIES AND GENRE" in the end.

df5['MOVIES AND GENRE']=df5['MOVIES']+df5['GENRE']

# %%
df5
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
#
#                                         GENRE    VOTES         YEAR  RATING  \
# 0      \nAction, Horror, Thriller               21,062       (2021)     6.1
# 1  \nAnimation, Action, Adventure               17,870     (2021– )     5.0
# 2       \nDrama, Horror, Thriller              885,805  (2010–2022)     8.2
#
#                                     MOVIES AND GENRE
# 0  Blood Red Sky\nAction, Horror, Thriller       ...
# 1  Masters of the Universe: Revelation\nAnimation...
# 2  The Walking Dead\nDrama, Horror, Thriller     ...

# %% [markdown]
# ## 28 Discretize a continuous column into bins.

# %%
pd.cut(df5['RATING'], bins=3)
# Out:
# 0    (6.067, 7.133]
# 1    (4.997, 6.067]
# 2      (7.133, 8.2]
# Name: RATING, dtype: category
# Categories (3, interval[float64, right]): [(4.997, 6.067] < (6.067, 7.133] < (7.133, 8.2]]

# %% [markdown]
# ## 29 Create polynomial features from existing numerical columns.

# %%
# Importing library PolynomialFeatures

from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2)
x = poly_features.fit_transform(df5[['RATING']])
x
# Out:
# array([[ 1.  ,  6.1 , 37.21],
#        [ 1.  ,  5.  , 25.  ],
#        [ 1.  ,  8.2 , 67.24]])
